# %%
# This notebook matches older gama catalogs against newer ones.
# The use case was: We had manual vetting done on GAMA09E and F and since have gotten new data.
# Since we then had to redo the whole chain of reductions, stacking and detections,
# objects IDs in the newer catalog changed.

# %%
# go wide screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from astropy.io import ascii
import numpy as np

# %%
told = ascii.read("../data/gama09EF.cat")

# %%
tnew = ascii.read("../data/augm_gama09EFGHfin_2.0.cat")

# %%
# determine set of fields
fields = np.unique(tnew['field'])

# %%
# determin existing ifus per field
ifus = {}
for field in fields:
    ii = tnew['field'] == field
    ifus[field] = np.unique(tnew[ii]["ifu"])

# %%
cat10 = ascii.read("../catalog_1.0.txt")

# %%
with open("../catalog_1.0_match_2.0.txt", 'w') as fout:
    for r in cat10[:]:
        #print("field {} ifu {}".format(field, ifu))
        ii  = told['field'] == r['field']
        ii *= told['ifu']   == "{:03d}".format(int(r['ifu']))
        ii *= told['id']   == r['id']

        if not np.sum(ii) == 1:
            print("SOMETHING BAD HAPPENED")
        #print("sum(ii) = {}".format(sum(ii)))

        jj  = tnew['field'] == r['field'] + 'fin'
        jj *= tnew['ifu']   == "{:03d}".format(int(r['ifu']))  

        #print("sum(jj) = {}".format(sum(jj)))

        x,y,z = told['x_com'][ii][0], told['z_com'][ii][0], told['z_com'][ii][0]
        X,Y,Z = tnew['x_com'][jj], tnew['z_com'][jj], tnew['z_com'][jj]

        d3d = np.sqrt((X-x)**2. + (Y-y)**2. + (Z-z)**2. )

        ix = np.argmin(d3d)
        s = ""
        rold = told[ii][0]
        rnew = tnew[jj][ix]
        if d3d[ix] <= 3.:
            #print("Closest matching source for old {} is {} distance is {:.2f}".format(told['id'][ii][0] , tnew['id'][jj][ix], d3d[ix] ))

            s = "{}\t{:03d}\t{}\t{}\t{:03d}\t{}".format(rold['field'], int(rold['ifu']), rold['id'], rnew['field'], int(rnew['ifu']), rnew['id'] )
        else:
            print("Closest matching source for old {} is {} distance is {:.2f}".format(told['id'][ii][0] , tnew['id'][jj][ix], d3d[ix] ))
            s = "{}\t{:03d}\t{}\t{}\t{}\t{}".format(rold['field'], int(rold['ifu']), rold['id'], "","","")
        print(s)
        fout.write(s + '\n')
# Out:
# gama09E	014	81	gama09Efin	014	98
# Closest matching source for old 8 is 19 distance is 21.78
# gama09E	016	8
# gama09E	016	10	gama09Efin	016	19
# Closest matching source for old 53 is 178 distance is 7.22
# gama09E	016	53
# Closest matching source for old 135 is 443 distance is 10.64
# gama09E	016	135
# gama09E	016	143	gama09Efin	016	471
# Closest matching source for old 28 is 69 distance is 14.31
# gama09E	024	28
# Closest matching source for old 68 is 163 distance is 16.28
# gama09E	024	68
# Closest matching source for old 131 is 235 distance is 44.49
# gama09E	024	131
# gama09E	024	189	gama09Efin	024	327
# gama09E	026	2	gama09Efin	026	2
# gama09E	026	22	gama09Efin	026	23
# gama09E	028	30	gama09Efin	028	28
# gama09E	028	67	gama09Efin	028	72
# gama09E	028	137	gama09Efin	028	183
# gama09E	032	8	gama09Efin	032	5
# Closest matching source for old 7 is 6 distance is 23.31
# gama09E	033	7
# gama09E	033	44	gama09Efin	033	62
# gama09E	034	54	gama09Efin	034	61
# gama09E	014	81	gama09Efin	014	98
# Closest matching source for old 8 is 19 distance is 21.78
# gama09E	016	8
# gama09E	016	10	gama09Efin	016	19
# Closest matching source for old 53 is 178 distance is 7.22
# gama09E	016	53
# Closest matching source for old 135 is 443 distance is 10.64
# gama09E	016	135
# gama09E	016	143	gama09Efin	016	471
# gama09E	021	6	gama09Efin	021	9
# gama09E	021	8	gama09Efin	021	12
# gama09E	023	8	gama09Efin	023	15
# gama09E	023	17	gama09Efin	023	28
# gama09E	023	195	gama09Efin	023	216
# Closest matching source for old 28 is 69 distance is 14.31
# gama09E	024	28
# Closest matching source for old 68 is 163 distance is 16.28
# gama09E	024	68
# Closest matching source for old 131 is 235 distance is 44.49
# gama09E	024	131
# gama09E	024	189	gama09Efin	024	327
# Closest matching source for old 9 is 15 distance is 3.03
# gama09E	025	9
# gama09E	026	2	gama09Efin	026	2
# gama09E	027	17	gama09Efin	027	22
# gama09E	028	30	gama09Efin	028	28
# gama09E	028	67	gama09Efin	028	72
# gama09E	028	137	gama09Efin	028	183
# gama09E	032	8	gama09Efin	032	5
# Closest matching source for old 7 is 6 distance is 23.31
# gama09E	033	7
# Closest matching source for old 10 is 24 distance is 21.28
# gama09E	033	10
# gama09E	033	41	gama09Efin	033	56
# gama09E	034	54	gama09Efin	034	61
# gama09E	035	24	gama09Efin	035	29
# gama09E	035	52	gama09Efin	035	62
# gama09E	035	100	gama09Efin	035	100
# Closest matching source for old 127 is 161 distance is 57.75
# gama09E	036	127
# gama09E	036	202	gama09Efin	036	215
# gama09E	041	12	gama09Efin	041	13
# gama09E	042	13	gama09Efin	042	20
# Closest matching source for old 22 is 25 distance is 7.11
# gama09E	042	22
# Closest matching source for old 35 is 40 distance is 3.93
# gama09E	042	35
# gama09E	042	83	gama09Efin	042	97
# gama09E	042	152	gama09Efin	042	187
# Closest matching source for old 169 is 211 distance is 11.28
# gama09E	042	169
# gama09E	043	23	gama09Efin	043	41
# gama09E	043	181	gama09Efin	043	212
# gama09E	044	28	gama09Efin	044	31
# gama09E	046	40	gama09Efin	046	43
# gama09E	046	52	gama09Efin	046	54
# gama09E	046	107	gama09Efin	046	91
# gama09E	046	110	gama09Efin	046	95
# Closest matching source for old 145 is 116 distance is 4.74
# gama09E	046	145
# gama09E	047	72	gama09Efin	047	54
# Closest matching source for old 10 is 6 distance is 19.36
# gama09E	048	10
# gama09E	053	45	gama09Efin	053	43
# gama09E	062	10	gama09Efin	062	15
# gama09E	062	124	gama09Efin	062	224
# gama09E	067	52	gama09Efin	067	41
# gama09E	068	13	gama09Efin	068	17
# gama09E	068	27	gama09Efin	068	38
# gama09E	068	35	gama09Efin	068	46
# Closest matching source for old 3 is 4 distance is 4.20
# gama09E	071	3
# Closest matching source for old 9 is 4 distance is 3.45
# gama09E	071	9
# Closest matching source for old 13 is 5 distance is 11.34
# gama09E	071	13
# Closest matching source for old 22 is 21 distance is 11.31
# gama09E	071	22
# Closest matching source for old 23 is 15 distance is 3.16
# gama09E	071	23
# Closest matching source for old 25 is 21 distance is 8.57
# gama09E	071	25
# gama09E	071	29	gama09Efin	071	19
# Closest matching source for old 33 is 28 distance is 4.16
# gama09E	071	33
# Closest matching source for old 48 is 20 distance is 8.69
# gama09E	071	48
# Closest matching source for old 52 is 25 distance is 10.45
# gama09E	071	52
# Closest matching source for old 58 is 29 distance is 12.39
# gama09E	071	58
# Closest matching source for old 68 is 43 distance is 19.23
# gama09E	071	68
# Closest matching source for old 79 is 44 distance is 3.95
# gama09E	071	79
# Closest matching source for old 108 is 57 distance is 7.60
# gama09E	071	108
# Closest matching source for old 112 is 57 distance is 4.52
# gama09E	071	112
# gama09E	071	114	gama09Efin	071	57
# gama09E	071	129	gama09Efin	071	67
# Closest matching source for old 139 is 67 distance is 7.89
# gama09E	071	139
# Closest matching source for old 249 is 116 distance is 6.78
# gama09E	071	249
# Closest matching source for old 254 is 116 distance is 8.80
# gama09E	071	254
# Closest matching source for old 624 is 236 distance is 9.02
# gama09E	071	624
# gama09E	072	9	gama09Efin	072	12
# gama09E	072	13	gama09Efin	072	17
# gama09E	073	24	gama09Efin	073	28
# Closest matching source for old 26 is 30 distance is 6.50
# gama09E	073	26
# gama09E	073	34	gama09Efin	073	36
# Closest matching source for old 36 is 37 distance is 5.23
# gama09E	073	36
# gama09E	075	62	gama09Efin	075	92
# gama09E	075	217	gama09Efin	075	227
# gama09E	075	259	gama09Efin	075	260
# gama09E	077	12	gama09Efin	077	12
# gama09E	077	48	gama09Efin	077	48
# gama09E	079	55	gama09Efin	079	62
# gama09E	079	153	gama09Efin	079	135
# Closest matching source for old 10 is 24 distance is 8.14
# gama09E	083	10
# gama09E	084	24	gama09Efin	084	37
# gama09E	085	5	gama09Efin	085	11
# gama09E	085	41	gama09Efin	085	69
# Closest matching source for old 82 is 118 distance is 6.22
# gama09E	085	82
# gama09E	085	164	gama09Efin	085	251
# gama09E	086	7	gama09Efin	086	8
# Closest matching source for old 8 is 21 distance is 12.32
# gama09E	086	8
# gama09E	086	15	gama09Efin	086	20
# gama09E	086	217	gama09Efin	086	398
# gama09E	088	28	gama09Efin	088	46
# gama09E	088	72	gama09Efin	088	88
# gama09E	088	106	gama09Efin	088	117
# gama09E	094	41	gama09Efin	094	37
# gama09E	094	94	gama09Efin	094	93
# gama09E	094	137	gama09Efin	094	154
# gama09E	095	3	gama09Efin	095	3
# gama09E	095	124	gama09Efin	095	68
# gama09E	096	26	gama09Efin	096	21
# gama09E	096	31	gama09Efin	096	32
# Closest matching source for old 3 is 9 distance is 14.03
# gama09E	097	3
# gama09E	097	101	gama09Efin	097	118
# gama09E	097	122	gama09Efin	097	151
# gama09E	097	220	gama09Efin	097	266
# Closest matching source for old 53 is 36 distance is 7.39
# gama09E	098	53
# gama09E	098	174	gama09Efin	098	157
# gama09E	103	39	gama09Efin	103	49
# gama09E	104	7	gama09Efin	104	10
# gama09E	104	45	gama09Efin	104	44
# gama09F	013	29	gama09Ffin	013	25
# gama09F	013	47	gama09Ffin	013	39
# gama09F	014	113	gama09Ffin	014	132
# gama09F	021	287	gama09Ffin	021	192
# gama09F	022	86	gama09Ffin	022	115
# gama09F	024	3	gama09Ffin	024	1
# gama09F	024	98	gama09Ffin	024	231
# gama09F	027	87	gama09Ffin	027	65
# gama09F	027	164	gama09Ffin	027	127
# gama09F	031	248	gama09Ffin	031	235
# Closest matching source for old 11 is 6 distance is 6.49
# gama09F	032	11
# gama09F	032	51	gama09Ffin	032	42
# gama09F	032	122	gama09Ffin	032	89
# Closest matching source for old 3 is 3 distance is 16.19
# gama09F	033	3
# Closest matching source for old 49 is 36 distance is 7.00
# gama09F	033	49
# gama09F	034	170	gama09Ffin	034	127
# gama09F	035	372	gama09Ffin	035	232
# Closest matching source for old 453 is 269 distance is 5.90
# gama09F	035	453
# gama09F	037	121	gama09Ffin	037	99
# gama09F	037	153	gama09Ffin	037	118
# gama09F	037	235	gama09Ffin	037	162
# gama09F	037	332	gama09Ffin	037	226
# gama09F	037	336	gama09Ffin	037	230
# gama09F	038	88	gama09Ffin	038	65
# gama09F	042	3	gama09Ffin	042	3
# gama09F	042	6	gama09Ffin	042	7
# Closest matching source for old 66 is 49 distance is 11.14
# gama09F	042	66
# gama09F	042	72	gama09Ffin	042	54
# gama09F	042	119	gama09Ffin	042	90
# gama09F	043	135	gama09Ffin	043	90
# Closest matching source for old 12 is 4 distance is 34.14
# gama09F	044	12
# gama09F	044	33	gama09Ffin	044	26
# gama09F	044	62	gama09Ffin	044	46
# gama09F	045	107	gama09Ffin	045	70
# gama09F	048	21	gama09Ffin	048	30
# gama09F	048	325	gama09Ffin	048	262
# Closest matching source for old 6 is 3 distance is 6.29
# gama09F	053	6
# gama09F	053	14	gama09Ffin	053	15
# gama09F	053	49	gama09Ffin	053	66
# gama09F	053	75	gama09Ffin	053	92
# gama09F	062	1	gama09Ffin	062	2
# gama09F	062	3	gama09Ffin	062	5
# gama09F	062	10	gama09Ffin	062	16
# Closest matching source for old 40 is 67 distance is 10.72
# gama09F	062	40
# gama09F	062	194	gama09Ffin	062	305
# gama09F	063	103	gama09Ffin	063	99
# gama09F	063	113	gama09Ffin	063	107
# gama09F	067	12	gama09Ffin	067	7
# gama09F	067	13	gama09Ffin	067	8
# gama09F	067	14	gama09Ffin	067	5
# gama09F	067	25	gama09Ffin	067	15
# gama09F	067	37	gama09Ffin	067	29
# gama09F	067	57	gama09Ffin	067	34
# Closest matching source for old 134 is 104 distance is 4.59
# gama09F	067	134
# Closest matching source for old 146 is 101 distance is 10.80
# gama09F	067	146
# gama09F	067	375	gama09Ffin	067	233
# Closest matching source for old 7 is 3 distance is 6.82
# gama09F	071	7
# Closest matching source for old 14 is 9 distance is 3.39
# gama09F	071	14
# gama09F	072	248	gama09Ffin	072	201
# gama09F	076	199	gama09Ffin	076	83
# gama09F	077	241	gama09Ffin	077	241
# Closest matching source for old 44 is 46 distance is 9.77
# gama09F	079	44
# gama09F	082	201	gama09Ffin	082	169
# gama09F	084	8	gama09Ffin	084	8
# gama09F	084	176	gama09Ffin	084	145
# gama09F	087	61	gama09Ffin	087	63
# gama09F	087	85	gama09Ffin	087	85
# gama09F	087	384	gama09Ffin	087	364
# gama09F	087	418	gama09Ffin	087	399
# gama09F	088	346	gama09Ffin	088	381
# gama09F	093	134	gama09Ffin	093	114
# gama09F	094	2	gama09Ffin	094	2
# gama09F	094	203	gama09Ffin	094	137
# gama09F	095	180	gama09Ffin	095	180
# Closest matching source for old 13 is 18 distance is 4.31
# gama09F	096	13
# gama09F	096	209	gama09Ffin	096	232
# Closest matching source for old 26 is 25 distance is 7.57
# gama09F	097	26
# gama09F	097	196	gama09Ffin	097	182
# gama09F	098	436	gama09Ffin	098	377
# Closest matching source for old 13 is 3 distance is 4.17
# gama09F	103	13
# gama09F	103	16	gama09Ffin	103	9
# gama09F	103	17	gama09Ffin	103	11
# gama09F	103	24	gama09Ffin	103	13
# Closest matching source for old 25 is 16 distance is 3.21
# gama09F	103	25
# Closest matching source for old 36 is 24 distance is 4.30
# gama09F	103	36
# Closest matching source for old 50 is 27 distance is 8.38
# gama09F	103	50
# gama09F	103	60	gama09Ffin	103	37
# Closest matching source for old 63 is 43 distance is 6.24
# gama09F	103	63
# Closest matching source for old 82 is 51 distance is 3.85
# gama09F	103	82
# Closest matching source for old 90 is 55 distance is 5.21
# gama09F	103	90
# Closest matching source for old 91 is 59 distance is 13.75
# gama09F	103	91
# Closest matching source for old 102 is 60 distance is 4.44
# gama09F	103	102
# Closest matching source for old 115 is 63 distance is 3.93
# gama09F	103	115
# Closest matching source for old 143 is 70 distance is 9.54
# gama09F	103	143
# Closest matching source for old 163 is 88 distance is 8.71
# gama09F	103	163
# gama09F	103	178	gama09Ffin	103	91
# Closest matching source for old 194 is 94 distance is 6.15
# gama09F	103	194
# gama09F	103	195	gama09Ffin	103	97
# Closest matching source for old 23 is 28 distance is 5.57
# gama09F	105	23
# gama09F	105	203	gama09Ffin	105	184
# Closest matching source for old 314 is 280 distance is 4.29
# gama09F	105	314
# gama09F	106	64	gama09Ffin	106	34
# gama09F	106	84	gama09Ffin	106	59
# gama09F	106	125	gama09Ffin	106	89
# gama09E	013	10	gama09Efin	013	10
# Closest matching source for old 36 is 145 distance is 6.19
# gama09E	015	36
# Closest matching source for old 37 is 145 distance is 5.76
# gama09E	015	37
# Closest matching source for old 65 is 224 distance is 5.13
# gama09E	015	65
# Closest matching source for old 56 is 201 distance is 5.74
# gama09E	016	56
# gama09E	016	88	gama09Efin	016	275
# gama09E	016	155	gama09Efin	016	520
# gama09E	022	121	gama09Efin	022	118
# gama09E	023	65	gama09Efin	023	82
# gama09E	023	75	gama09Efin	023	93
# gama09E	023	149	gama09Efin	023	168
# Closest matching source for old 199 is 219 distance is 10.16
# gama09E	023	199
# Closest matching source for old 11 is 32 distance is 7.50
# gama09E	024	11
# Closest matching source for old 45 is 122 distance is 28.26
# gama09E	024	45
# gama09E	024	60	gama09Efin	024	149
# Closest matching source for old 66 is 163 distance is 8.90
# gama09E	024	66
# Closest matching source for old 115 is 224 distance is 12.19
# gama09E	024	115
# Closest matching source for old 176 is 300 distance is 44.30
# gama09E	024	176
# gama09E	025	34	gama09Efin	025	37
# Closest matching source for old 189 is 186 distance is 16.68
# gama09E	025	189
# Closest matching source for old 9 is 9 distance is 16.02
# gama09E	027	9
# gama09E	034	51	gama09Efin	034	59
# Closest matching source for old 32 is 41 distance is 27.44
# gama09E	035	32
# gama09E	036	50	gama09Efin	036	69
# Closest matching source for old 199 is 214 distance is 17.49
# gama09E	036	199
# gama09E	041	217	gama09Efin	041	297
# gama09E	042	5	gama09Efin	042	9
# Closest matching source for old 24 is 25 distance is 24.36
# gama09E	042	24
# gama09E	043	276	gama09Efin	043	308
# gama09E	044	13	gama09Efin	044	11
# gama09E	046	64	gama09Efin	046	62
# gama09E	046	70	gama09Efin	046	67
# Closest matching source for old 74 is 1 distance is 13.57
# gama09E	046	74
# gama09E	046	144	gama09Efin	046	116
# gama09E	046	147	gama09Efin	046	118
# gama09E	047	14	gama09Efin	047	12
# gama09E	047	33	gama09Efin	047	27
# Closest matching source for old 43 is 64 distance is 9.01
# gama09E	062	43
# Closest matching source for old 13 is 11 distance is 16.98
# gama09E	067	13
# gama09E	067	22	gama09Efin	067	16
# Closest matching source for old 36 is 30 distance is 8.87
# gama09E	067	36
# Closest matching source for old 18 is 10 distance is 4.80
# gama09E	071	18
# Closest matching source for old 26 is 21 distance is 5.23
# gama09E	071	26
# Closest matching source for old 50 is 25 distance is 12.53
# gama09E	071	50
# Closest matching source for old 53 is 25 distance is 11.10
# gama09E	071	53
# Closest matching source for old 73 is 43 distance is 12.88
# gama09E	071	73
# gama09E	071	91	gama09Efin	071	52
# Closest matching source for old 97 is 54 distance is 10.28
# gama09E	071	97
# Closest matching source for old 154 is 66 distance is 17.21
# gama09E	071	154
# Closest matching source for old 158 is 76 distance is 10.60
# gama09E	071	158
# Closest matching source for old 179 is 81 distance is 7.95
# gama09E	071	179
# Closest matching source for old 200 is 90 distance is 8.86
# gama09E	071	200
# Closest matching source for old 371 is 163 distance is 12.55
# gama09E	071	371
# Closest matching source for old 520 is 204 distance is 13.07
# gama09E	071	520
# Closest matching source for old 541 is 207 distance is 6.79
# gama09E	071	541
# gama09E	071	564	gama09Efin	071	217
# Closest matching source for old 795 is 298 distance is 19.85
# gama09E	071	795
# gama09E	072	131	gama09Efin	072	133
# gama09E	073	42	gama09Efin	073	40
# gama09E	073	45	gama09Efin	073	42
# Closest matching source for old 105 is 93 distance is 14.16
# gama09E	073	105
# gama09E	074	15	gama09Efin	074	19
# gama09E	074	165	gama09Efin	074	157
# Closest matching source for old 12 is 9 distance is 17.45
# gama09E	075	12
# Closest matching source for old 40 is 62 distance is 4.78
# gama09E	075	40
# gama09E	075	98	gama09Efin	075	121
# gama09E	075	146	gama09Efin	075	160
# gama09E	079	53	gama09Efin	079	59
# gama09E	079	92	gama09Efin	079	95
# gama09E	083	35	gama09Efin	083	63
# gama09E	083	62	gama09Efin	083	95
# Closest matching source for old 34 is 52 distance is 16.15
# gama09E	084	34
# gama09E	084	135	gama09Efin	084	158
# gama09E	086	78	gama09Efin	086	147
# gama09E	087	156	gama09Efin	087	197
# gama09E	091	137	gama09Efin	091	150
# Closest matching source for old 33 is 37 distance is 6.43
# gama09E	092	33
# gama09E	094	60	gama09Efin	094	54
# gama09E	094	133	gama09Efin	094	143
# gama09E	095	49	gama09Efin	095	32
# gama09E	097	53	gama09Efin	097	61
# Closest matching source for old 147 is 128 distance is 10.03
# gama09E	098	147
# gama09E	104	13	gama09Efin	104	14
# Closest matching source for old 29 is 26 distance is 10.13
# gama09E	104	29
# gama09E	104	33	gama09Efin	104	30
# Closest matching source for old 82 is 71 distance is 23.68
# gama09E	104	82
# Closest matching source for old 104 is 97 distance is 4.95
# gama09E	104	104
# gama09E	104	151	gama09Efin	104	145
# gama09E	106	25	gama09Efin	106	40
# gama09E	106	34	gama09Efin	106	53
# gama09F	014	22	gama09Ffin	014	23
# gama09F	014	24	gama09Ffin	014	22
# gama09F	014	182	gama09Ffin	014	205
# gama09F	016	34	gama09Ffin	016	32
# Closest matching source for old 235 is 164 distance is 9.00
# gama09F	021	235
# gama09F	022	12	gama09Ffin	022	17
# Closest matching source for old 73 is 147 distance is 23.21
# gama09F	024	73
# gama09F	027	185	gama09Ffin	027	141
# gama09F	032	39	gama09Ffin	032	34
# Closest matching source for old 140 is 96 distance is 22.65
# gama09F	032	140
# Closest matching source for old 17 is 13 distance is 29.94
# gama09F	034	17
# gama09F	034	33	gama09Ffin	034	25
# gama09F	035	164	gama09Ffin	035	119
# Closest matching source for old 413 is 250 distance is 7.05
# gama09F	035	413
# gama09F	035	522	gama09Ffin	035	296
# Closest matching source for old 561 is 327 distance is 6.28
# gama09F	035	561
# Closest matching source for old 149 is 153 distance is 7.20
# gama09F	036	149
# gama09F	037	16	gama09Ffin	037	16
# gama09F	041	66	gama09Ffin	041	124
# gama09F	041	170	gama09Ffin	041	305
# gama09F	042	4	gama09Ffin	042	4
# gama09F	043	197	gama09Ffin	043	140
# gama09F	043	221	gama09Ffin	043	158
# gama09F	044	63	gama09Ffin	044	45
# gama09F	048	15	gama09Ffin	048	21
# gama09F	053	16	gama09Ffin	053	10
# gama09F	053	192	gama09Ffin	053	247
# gama09F	053	203	gama09Ffin	053	257
# gama09F	062	25	gama09Ffin	062	40
# gama09F	062	89	gama09Ffin	062	158
# Closest matching source for old 98 is 71 distance is 3.23
# gama09F	067	98
# Closest matching source for old 193 is 156 distance is 8.88
# gama09F	067	193
# gama09F	072	209	gama09Ffin	072	174
# gama09F	077	136	gama09Ffin	077	136
# Closest matching source for old 82 is 86 distance is 10.20
# gama09F	079	82
# gama09F	081	68	gama09Ffin	081	67
# gama09F	082	84	gama09Ffin	082	80
# gama09F	084	200	gama09Ffin	084	162
# gama09F	084	227	gama09Ffin	084	180
# gama09F	086	36	gama09Ffin	086	41
# gama09F	087	11	gama09Ffin	087	12
# gama09F	087	70	gama09Ffin	087	69
# gama09F	087	131	gama09Ffin	087	136
# Closest matching source for old 152 is 165 distance is 12.74
# gama09F	087	152
# gama09F	087	380	gama09Ffin	087	359
# gama09F	091	52	gama09Ffin	091	44
# Closest matching source for old 67 is 60 distance is 5.43
# gama09F	091	67
# gama09F	091	122	gama09Ffin	091	111
# Closest matching source for old 133 is 114 distance is 25.34
# gama09F	091	133
# Closest matching source for old 139 is 119 distance is 8.84
# gama09F	091	139
# gama09F	092	68	gama09Ffin	092	53
# gama09F	093	188	gama09Ffin	093	165
# gama09F	095	50	gama09Ffin	095	50
# gama09F	095	241	gama09Ffin	095	241
# gama09F	095	246	gama09Ffin	095	246
# gama09F	096	319	gama09Ffin	096	359
# gama09F	097	73	gama09Ffin	097	69
# Closest matching source for old 227 is 211 distance is 5.13
# gama09F	097	227
# gama09F	097	318	gama09Ffin	097	292
# Closest matching source for old 368 is 325 distance is 4.53
# gama09F	097	368
# gama09F	098	408	gama09Ffin	098	351
# Closest matching source for old 61 is 34 distance is 4.59
# gama09F	103	61
# gama09F	103	77	gama09Ffin	103	45
# Closest matching source for old 95 is 55 distance is 4.48
# gama09F	103	95
# gama09F	103	155	gama09Ffin	103	81
# Closest matching source for old 240 is 120 distance is 4.74
# gama09F	103	240
# Closest matching source for old 53 is 59 distance is 8.50
# gama09F	105	53
# gama09F	106	21	gama09Ffin	106	9
# gama09F	106	31	gama09Ffin	106	13
# Closest matching source for old 37 is 18 distance is 35.24
# gama09F	106	37
# Closest matching source for old 40 is 18 distance is 12.85
# gama09F	106	40
# gama09E	013	24	gama09Efin	013	34
# gama09E	013	64	gama09Efin	013	94
# gama09E	013	71	gama09Efin	013	104
# gama09E	014	23	gama09Efin	014	22
# gama09E	014	26	gama09Efin	014	28
# Closest matching source for old 31 is 36 distance is 18.31
# gama09E	014	31
# Closest matching source for old 22 is 71 distance is 4.52
# gama09E	015	22
# Closest matching source for old 35 is 142 distance is 8.09
# gama09E	015	35
# gama09E	015	72	gama09Efin	015	253
# gama09E	016	9	gama09Efin	016	21
# Closest matching source for old 59 is 216 distance is 6.49
# gama09E	016	59
# gama09E	016	113	gama09Efin	016	368
# Closest matching source for old 122 is 401 distance is 4.15
# gama09E	016	122
# gama09E	021	25	gama09Efin	021	31
# gama09E	021	42	gama09Efin	021	48
# gama09E	021	92	gama09Efin	021	111
# gama09E	022	6	gama09Efin	022	7
# Closest matching source for old 70 is 72 distance is 5.30
# gama09E	022	70
# Closest matching source for old 86 is 89 distance is 3.20
# gama09E	022	86
# Closest matching source for old 153 is 151 distance is 4.97
# gama09E	022	153
# Closest matching source for old 157 is 154 distance is 7.66
# gama09E	022	157
# Closest matching source for old 165 is 159 distance is 33.51
# gama09E	022	165
# Closest matching source for old 171 is 161 distance is 10.45
# gama09E	022	171
# Closest matching source for old 195 is 184 distance is 8.35
# gama09E	022	195
# gama09E	023	62	gama09Efin	023	79
# Closest matching source for old 84 is 101 distance is 8.30
# gama09E	023	84
# Closest matching source for old 114 is 132 distance is 18.96
# gama09E	023	114
# Closest matching source for old 174 is 193 distance is 3.06
# gama09E	023	174
# gama09E	023	188	gama09Efin	023	211
# Closest matching source for old 191 is 211 distance is 14.57
# gama09E	023	191
# Closest matching source for old 30 is 69 distance is 4.57
# gama09E	024	30
# Closest matching source for old 49 is 122 distance is 4.81
# gama09E	024	49
# Closest matching source for old 51 is 108 distance is 47.93
# gama09E	024	51
# Closest matching source for old 57 is 141 distance is 4.21
# gama09E	024	57
# Closest matching source for old 77 is 173 distance is 16.67
# gama09E	024	77
# Closest matching source for old 83 is 163 distance is 37.53
# gama09E	024	83
# Closest matching source for old 86 is 186 distance is 25.80
# gama09E	024	86
# Closest matching source for old 89 is 185 distance is 18.35
# gama09E	024	89
# Closest matching source for old 95 is 186 distance is 16.82
# gama09E	024	95
# Closest matching source for old 108 is 211 distance is 19.87
# gama09E	024	108
# Closest matching source for old 118 is 227 distance is 17.50
# gama09E	024	118
# Closest matching source for old 125 is 233 distance is 4.85
# gama09E	024	125
# Closest matching source for old 134 is 244 distance is 9.75
# gama09E	024	134
# Closest matching source for old 135 is 250 distance is 46.61
# gama09E	024	135
# Closest matching source for old 147 is 264 distance is 11.20
# gama09E	024	147
# Closest matching source for old 156 is 273 distance is 9.68
# gama09E	024	156
# Closest matching source for old 178 is 311 distance is 33.44
# gama09E	024	178
# Closest matching source for old 179 is 311 distance is 30.34
# gama09E	024	179
# Closest matching source for old 190 is 327 distance is 5.43
# gama09E	024	190
# Closest matching source for old 191 is 327 distance is 20.79
# gama09E	024	191
# gama09E	025	54	gama09Efin	025	59
# Closest matching source for old 59 is 65 distance is 6.19
# gama09E	025	59
# gama09E	025	62	gama09Efin	025	67
# gama09E	025	67	gama09Efin	025	69
# Closest matching source for old 76 is 72 distance is 19.88
# gama09E	025	76
# gama09E	025	87	gama09Efin	025	87
# Closest matching source for old 90 is 93 distance is 7.51
# gama09E	025	90
# Closest matching source for old 154 is 160 distance is 17.76
# gama09E	025	154
# gama09E	025	163	gama09Efin	025	166
# gama09E	025	210	gama09Efin	025	205
# Closest matching source for old 55 is 48 distance is 18.10
# gama09E	026	55
# Closest matching source for old 30 is 42 distance is 7.74
# gama09E	027	30
# Closest matching source for old 43 is 65 distance is 3.23
# gama09E	027	43
# Closest matching source for old 78 is 130 distance is 33.68
# gama09E	027	78
# Closest matching source for old 18 is 10 distance is 27.83
# gama09E	028	18
# gama09E	028	40	gama09Efin	028	41
# gama09E	028	120	gama09Efin	028	153
# Closest matching source for old 134 is 186 distance is 23.06
# gama09E	028	134
# gama09E	031	67	gama09Efin	031	61
# Closest matching source for old 21 is 16 distance is 15.12
# gama09E	032	21
# gama09E	033	4	gama09Efin	033	6
# Closest matching source for old 37 is 49 distance is 13.54
# gama09E	033	37
# gama09E	033	61	gama09Efin	033	86
# Closest matching source for old 96 is 119 distance is 32.44
# gama09E	033	96
# gama09E	034	41	gama09Efin	034	43
# Closest matching source for old 18 is 28 distance is 12.44
# gama09E	035	18
# gama09E	035	62	gama09Efin	035	73
# gama09E	035	92	gama09Efin	035	96
# gama09E	035	101	gama09Efin	035	101
# Closest matching source for old 105 is 102 distance is 11.28
# gama09E	035	105
# gama09E	036	64	gama09Efin	036	92
# Closest matching source for old 66 is 89 distance is 7.51
# gama09E	036	66
# Closest matching source for old 6 is 6 distance is 8.35
# gama09E	037	6
# gama09E	037	19	gama09Efin	037	20
# gama09E	038	80	gama09Efin	038	83
# gama09E	038	98	gama09Efin	038	106
# gama09E	041	23	gama09Efin	041	30
# Closest matching source for old 39 is 48 distance is 11.28
# gama09E	041	39
# gama09E	041	57	gama09Efin	041	79
# gama09E	041	58	gama09Efin	041	81
# gama09E	041	63	gama09Efin	041	87
# Closest matching source for old 88 is 125 distance is 5.14
# gama09E	041	88
# gama09E	041	119	gama09Efin	041	169
# gama09E	041	133	gama09Efin	041	184
# gama09E	041	202	gama09Efin	041	280
# gama09E	042	20	gama09Efin	042	25
# Closest matching source for old 56 is 62 distance is 6.00
# gama09E	042	56
# gama09E	042	61	gama09Efin	042	68
# gama09E	042	66	gama09Efin	042	76
# Closest matching source for old 79 is 96 distance is 14.77
# gama09E	042	79
# gama09E	042	81	gama09Efin	042	95
# gama09E	042	92	gama09Efin	042	104
# gama09E	042	93	gama09Efin	042	106
# Closest matching source for old 110 is 138 distance is 6.47
# gama09E	042	110
# Closest matching source for old 114 is 146 distance is 5.76
# gama09E	042	114
# Closest matching source for old 134 is 170 distance is 19.75
# gama09E	042	134
# gama09E	042	142	gama09Efin	042	178
# gama09E	042	161	gama09Efin	042	199
# gama09E	043	17	gama09Efin	043	26
# Closest matching source for old 21 is 39 distance is 10.08
# gama09E	043	21
# Closest matching source for old 46 is 82 distance is 3.37
# gama09E	043	46
# gama09E	043	67	gama09Efin	043	102
# gama09E	043	73	gama09Efin	043	108
# Closest matching source for old 103 is 135 distance is 5.23
# gama09E	043	103
# gama09E	043	106	gama09Efin	043	141
# Closest matching source for old 222 is 253 distance is 8.46
# gama09E	043	222
# Closest matching source for old 294 is 335 distance is 3.02
# gama09E	043	294
# Closest matching source for old 9 is 6 distance is 9.38
# gama09E	045	9
# Closest matching source for old 44 is 29 distance is 15.05
# gama09E	045	44
# gama09E	046	114	gama09Efin	046	97
# Closest matching source for old 141 is 117 distance is 11.55
# gama09E	046	141
# Closest matching source for old 148 is 118 distance is 3.86
# gama09E	046	148
# gama09E	046	149	gama09Efin	046	119
# Closest matching source for old 25 is 18 distance is 18.92
# gama09E	052	25
# Closest matching source for old 29 is 19 distance is 13.85
# gama09E	052	29
# gama09E	052	34	gama09Efin	052	33
# Closest matching source for old 85 is 68 distance is 10.57
# gama09E	052	85
# gama09E	062	3	gama09Efin	062	13
# gama09E	062	5	gama09Efin	062	9
# Closest matching source for old 12 is 17 distance is 7.56
# gama09E	062	12
# Closest matching source for old 11 is 11 distance is 9.46
# gama09E	067	11
# Closest matching source for old 28 is 11 distance is 14.21
# gama09E	067	28
# gama09E	067	41	gama09Efin	067	32
# Closest matching source for old 64 is 51 distance is 7.40
# gama09E	067	64
# gama09E	067	90	gama09Efin	067	84
# gama09E	067	93	gama09Efin	067	89
# Closest matching source for old 97 is 85 distance is 8.33
# gama09E	067	97
# Closest matching source for old 184 is 196 distance is 13.59
# gama09E	067	184
# gama09E	067	240	gama09Efin	067	252
# gama09E	067	297	gama09Efin	067	310
# Closest matching source for old 45 is 81 distance is 4.16
# gama09E	068	45
# Closest matching source for old 8 is 4 distance is 11.89
# gama09E	071	8
# Closest matching source for old 17 is 9 distance is 12.07
# gama09E	071	17
# Closest matching source for old 38 is 20 distance is 5.90
# gama09E	071	38
# Closest matching source for old 42 is 25 distance is 6.26
# gama09E	071	42
# gama09E	071	46	gama09Efin	071	20
# Closest matching source for old 51 is 25 distance is 6.88
# gama09E	071	51
# Closest matching source for old 60 is 35 distance is 6.35
# gama09E	071	60
# Closest matching source for old 61 is 35 distance is 19.51
# gama09E	071	61
# Closest matching source for old 62 is 36 distance is 16.90
# gama09E	071	62
# Closest matching source for old 64 is 36 distance is 25.21
# gama09E	071	64
# Closest matching source for old 65 is 36 distance is 9.57
# gama09E	071	65
# Closest matching source for old 66 is 40 distance is 24.57
# gama09E	071	66
# Closest matching source for old 71 is 43 distance is 10.24
# gama09E	071	71
# Closest matching source for old 81 is 48 distance is 11.73
# gama09E	071	81
# gama09E	071	85	gama09Efin	071	38
# Closest matching source for old 90 is 48 distance is 7.00
# gama09E	071	90
# gama09E	071	94	gama09Efin	071	53
# Closest matching source for old 95 is 49 distance is 13.34
# gama09E	071	95
# Closest matching source for old 101 is 53 distance is 11.47
# gama09E	071	101
# Closest matching source for old 102 is 54 distance is 10.37
# gama09E	071	102
# Closest matching source for old 110 is 54 distance is 7.55
# gama09E	071	110
# Closest matching source for old 116 is 57 distance is 5.71
# gama09E	071	116
# Closest matching source for old 123 is 66 distance is 13.63
# gama09E	071	123
# Closest matching source for old 143 is 66 distance is 12.51
# gama09E	071	143
# Closest matching source for old 150 is 71 distance is 5.31
# gama09E	071	150
# Closest matching source for old 153 is 71 distance is 15.41
# gama09E	071	153
# Closest matching source for old 159 is 72 distance is 7.68
# gama09E	071	159
# Closest matching source for old 162 is 72 distance is 17.79
# gama09E	071	162
# Closest matching source for old 167 is 78 distance is 13.37
# gama09E	071	167
# Closest matching source for old 168 is 75 distance is 3.68
# gama09E	071	168
# Closest matching source for old 170 is 75 distance is 8.45
# gama09E	071	170
# Closest matching source for old 173 is 75 distance is 13.45
# gama09E	071	173
# Closest matching source for old 175 is 78 distance is 19.79
# gama09E	071	175
# Closest matching source for old 184 is 86 distance is 13.98
# gama09E	071	184
# Closest matching source for old 190 is 88 distance is 7.73
# gama09E	071	190
# gama09E	071	191	gama09Efin	071	85
# Closest matching source for old 192 is 88 distance is 7.48
# gama09E	071	192
# Closest matching source for old 194 is 90 distance is 8.95
# gama09E	071	194
# Closest matching source for old 195 is 90 distance is 9.86
# gama09E	071	195
# Closest matching source for old 197 is 88 distance is 3.83
# gama09E	071	197
# Closest matching source for old 210 is 94 distance is 7.54
# gama09E	071	210
# Closest matching source for old 214 is 100 distance is 17.39
# gama09E	071	214
# Closest matching source for old 215 is 91 distance is 18.34
# gama09E	071	215
# Closest matching source for old 218 is 103 distance is 12.47
# gama09E	071	218
# Closest matching source for old 222 is 95 distance is 7.65
# gama09E	071	222
# Closest matching source for old 230 is 106 distance is 3.03
# gama09E	071	230
# Closest matching source for old 232 is 103 distance is 3.69
# gama09E	071	232
# Closest matching source for old 237 is 106 distance is 4.94
# gama09E	071	237
# Closest matching source for old 244 is 109 distance is 9.78
# gama09E	071	244
# Closest matching source for old 252 is 112 distance is 6.19
# gama09E	071	252
# gama09E	071	257	gama09Efin	071	116
# gama09E	071	258	gama09Efin	071	117
# Closest matching source for old 264 is 116 distance is 15.83
# gama09E	071	264
# Closest matching source for old 276 is 125 distance is 9.53
# gama09E	071	276
# Closest matching source for old 291 is 136 distance is 10.74
# gama09E	071	291
# Closest matching source for old 306 is 137 distance is 9.45
# gama09E	071	306
# Closest matching source for old 317 is 146 distance is 3.09
# gama09E	071	317
# Closest matching source for old 335 is 150 distance is 10.26
# gama09E	071	335
# Closest matching source for old 348 is 83 distance is 10.49
# gama09E	071	348
# Closest matching source for old 350 is 156 distance is 7.52
# gama09E	071	350
# Closest matching source for old 359 is 162 distance is 9.42
# gama09E	071	359
# Closest matching source for old 361 is 163 distance is 11.39
# gama09E	071	361
# Closest matching source for old 367 is 164 distance is 8.08
# gama09E	071	367
# Closest matching source for old 375 is 165 distance is 7.28
# gama09E	071	375
# Closest matching source for old 376 is 166 distance is 5.67
# gama09E	071	376
# Closest matching source for old 381 is 167 distance is 6.94
# gama09E	071	381
# gama09E	071	382	gama09Efin	071	167
# Closest matching source for old 384 is 169 distance is 11.30
# gama09E	071	384
# Closest matching source for old 394 is 167 distance is 10.39
# gama09E	071	394
# Closest matching source for old 409 is 173 distance is 18.27
# gama09E	071	409
# Closest matching source for old 412 is 169 distance is 27.77
# gama09E	071	412
# Closest matching source for old 421 is 180 distance is 25.16
# gama09E	071	421
# Closest matching source for old 428 is 177 distance is 11.05
# gama09E	071	428
# Closest matching source for old 431 is 179 distance is 13.08
# gama09E	071	431
# Closest matching source for old 443 is 179 distance is 4.06
# gama09E	071	443
# Closest matching source for old 451 is 182 distance is 18.17
# gama09E	071	451
# Closest matching source for old 459 is 184 distance is 21.82
# gama09E	071	459
# Closest matching source for old 463 is 184 distance is 16.03
# gama09E	071	463
# Closest matching source for old 468 is 188 distance is 3.85
# gama09E	071	468
# Closest matching source for old 477 is 189 distance is 8.60
# gama09E	071	477
# Closest matching source for old 487 is 192 distance is 11.75
# gama09E	071	487
# Closest matching source for old 489 is 192 distance is 12.64
# gama09E	071	489
# Closest matching source for old 515 is 203 distance is 5.43
# gama09E	071	515
# Closest matching source for old 525 is 207 distance is 16.02
# gama09E	071	525
# Closest matching source for old 527 is 208 distance is 12.25
# gama09E	071	527
# Closest matching source for old 529 is 208 distance is 13.38
# gama09E	071	529
# Closest matching source for old 543 is 213 distance is 11.23
# gama09E	071	543
# Closest matching source for old 568 is 217 distance is 17.33
# gama09E	071	568
# Closest matching source for old 572 is 219 distance is 10.71
# gama09E	071	572
# Closest matching source for old 573 is 216 distance is 18.78
# gama09E	071	573
# Closest matching source for old 582 is 225 distance is 8.89
# gama09E	071	582
# Closest matching source for old 594 is 225 distance is 13.01
# gama09E	071	594
# Closest matching source for old 611 is 233 distance is 13.02
# gama09E	071	611
# gama09E	071	628	gama09Efin	071	239
# Closest matching source for old 631 is 241 distance is 9.00
# gama09E	071	631
# Closest matching source for old 638 is 245 distance is 10.64
# gama09E	071	638
# gama09E	071	651	gama09Efin	071	249
# gama09E	071	656	gama09Efin	071	252
# Closest matching source for old 661 is 254 distance is 10.01
# gama09E	071	661
# Closest matching source for old 664 is 257 distance is 3.47
# gama09E	071	664
# gama09E	071	668	gama09Efin	071	259
# Closest matching source for old 691 is 266 distance is 7.25
# gama09E	071	691
# Closest matching source for old 699 is 269 distance is 5.69
# gama09E	071	699
# Closest matching source for old 711 is 271 distance is 6.62
# gama09E	071	711
# Closest matching source for old 719 is 275 distance is 3.18
# gama09E	071	719
# Closest matching source for old 729 is 279 distance is 8.46
# gama09E	071	729
# Closest matching source for old 749 is 284 distance is 5.42
# gama09E	071	749
# Closest matching source for old 753 is 287 distance is 6.64
# gama09E	071	753
# Closest matching source for old 771 is 293 distance is 13.61
# gama09E	071	771
# Closest matching source for old 784 is 293 distance is 9.32
# gama09E	071	784
# Closest matching source for old 785 is 293 distance is 4.17
# gama09E	071	785
# Closest matching source for old 820 is 300 distance is 24.27
# gama09E	071	820
# Closest matching source for old 821 is 300 distance is 22.66
# gama09E	071	821
# Closest matching source for old 828 is 301 distance is 13.25
# gama09E	071	828
# Closest matching source for old 832 is 301 distance is 8.54
# gama09E	071	832
# Closest matching source for old 838 is 304 distance is 21.07
# gama09E	071	838
# Closest matching source for old 854 is 305 distance is 10.53
# gama09E	071	854
# Closest matching source for old 862 is 306 distance is 14.79
# gama09E	071	862
# Closest matching source for old 893 is 313 distance is 14.72
# gama09E	071	893
# Closest matching source for old 929 is 326 distance is 14.25
# gama09E	071	929
# gama09E	072	119	gama09Efin	072	115
# gama09E	072	126	gama09Efin	072	126
# gama09E	072	128	gama09Efin	072	129
# gama09E	072	132	gama09Efin	072	134
# gama09E	072	166	gama09Efin	072	167
# gama09E	072	186	gama09Efin	072	204
# gama09E	073	35	gama09Efin	073	38
# gama09E	073	38	gama09Efin	073	39
# gama09E	073	53	gama09Efin	073	51
# gama09E	073	64	gama09Efin	073	64
# gama09E	073	103	gama09Efin	073	93
# Closest matching source for old 110 is 99 distance is 20.89
# gama09E	073	110
# Closest matching source for old 186 is 175 distance is 10.49
# gama09E	073	186
# gama09E	073	190	gama09Efin	073	180
# gama09E	074	51	gama09Efin	074	58
# Closest matching source for old 72 is 83 distance is 13.00
# gama09E	074	72
# gama09E	074	115	gama09Efin	074	112
# gama09E	074	125	gama09Efin	074	117
# gama09E	075	28	gama09Efin	075	49
# Closest matching source for old 111 is 131 distance is 14.10
# gama09E	075	111
# gama09E	075	172	gama09Efin	075	184
# Closest matching source for old 175 is 188 distance is 3.30
# gama09E	075	175
# gama09E	075	189	gama09Efin	075	198
# gama09E	075	207	gama09Efin	075	219
# Closest matching source for old 209 is 219 distance is 14.33
# gama09E	075	209
# Closest matching source for old 233 is 235 distance is 15.05
# gama09E	075	233
# Closest matching source for old 253 is 253 distance is 5.49
# gama09E	075	253
# gama09E	075	256	gama09Efin	075	254
# gama09E	076	10	gama09Efin	076	9
# gama09E	076	11	gama09Efin	076	10
# gama09E	076	22	gama09Efin	076	17
# Closest matching source for old 28 is 24 distance is 10.77
# gama09E	076	28
# gama09E	077	23	gama09Efin	077	23
# gama09E	077	43	gama09Efin	077	43
# gama09E	077	57	gama09Efin	077	57
# gama09E	077	62	gama09Efin	077	62
# gama09E	077	110	gama09Efin	077	110
# gama09E	077	123	gama09Efin	077	123
# gama09E	077	128	gama09Efin	077	128
# gama09E	077	143	gama09Efin	077	143
# Closest matching source for old 18 is 21 distance is 17.05
# gama09E	079	18
# gama09E	079	64	gama09Efin	079	69
# Closest matching source for old 85 is 87 distance is 11.30
# gama09E	079	85
# gama09E	079	88	gama09Efin	079	89
# gama09E	079	90	gama09Efin	079	93
# gama09E	079	115	gama09Efin	079	106
# gama09E	079	129	gama09Efin	079	115
# Closest matching source for old 144 is 129 distance is 27.44
# gama09E	079	144
# gama09E	081	47	gama09Efin	081	19
# gama09E	081	48	gama09Efin	081	20
# Closest matching source for old 68 is 87 distance is 7.71
# gama09E	082	68
# gama09E	083	7	gama09Efin	083	17
# Closest matching source for old 21 is 47 distance is 16.23
# gama09E	083	21
# Closest matching source for old 31 is 51 distance is 12.18
# gama09E	083	31
# gama09E	083	68	gama09Efin	083	102
# gama09E	083	100	gama09Efin	083	154
# Closest matching source for old 121 is 175 distance is 15.28
# gama09E	083	121
# gama09E	083	138	gama09Efin	083	188
# gama09E	083	215	gama09Efin	083	275
# gama09E	084	21	gama09Efin	084	30
# gama09E	084	33	gama09Efin	084	51
# gama09E	084	106	gama09Efin	084	134
# gama09E	085	67	gama09Efin	085	99
# Closest matching source for old 154 is 236 distance is 17.82
# gama09E	085	154
# Closest matching source for old 163 is 248 distance is 13.22
# gama09E	085	163
# gama09E	086	44	gama09Efin	086	80
# gama09E	086	54	gama09Efin	086	111
# gama09E	086	62	gama09Efin	086	129
# gama09E	086	65	gama09Efin	086	129
# gama09E	086	94	gama09Efin	086	170
# gama09E	086	95	gama09Efin	086	171
# Closest matching source for old 108 is 191 distance is 7.35
# gama09E	086	108
# Closest matching source for old 156 is 273 distance is 13.11
# gama09E	086	156
# gama09E	086	251	gama09Efin	086	505
# gama09E	087	33	gama09Efin	087	39
# gama09E	087	49	gama09Efin	087	63
# gama09E	087	83	gama09Efin	087	99
# Closest matching source for old 144 is 183 distance is 5.05
# gama09E	087	144
# Closest matching source for old 21 is 33 distance is 9.35
# gama09E	088	21
# gama09E	088	66	gama09Efin	088	82
# gama09E	091	161	gama09Efin	091	183
# Closest matching source for old 28 is 30 distance is 8.10
# gama09E	092	28
# gama09E	092	98	gama09Efin	092	125
# gama09E	093	32	gama09Efin	093	53
# gama09E	093	53	gama09Efin	093	78
# gama09E	093	65	gama09Efin	093	91
# Closest matching source for old 75 is 95 distance is 11.71
# gama09E	093	75
# gama09E	093	80	gama09Efin	093	105
# gama09E	094	110	gama09Efin	094	113
# Closest matching source for old 113 is 113 distance is 7.87
# gama09E	094	113
# gama09E	094	135	gama09Efin	094	146
# gama09E	094	314	gama09Efin	094	332
# gama09E	095	44	gama09Efin	095	30
# Closest matching source for old 47 is 30 distance is 11.02
# gama09E	095	47
# gama09E	095	76	gama09Efin	095	42
# gama09E	095	119	gama09Efin	095	64
# gama09E	095	125	gama09Efin	095	69
# gama09E	095	132	gama09Efin	095	73
# Closest matching source for old 143 is 78 distance is 13.92
# gama09E	095	143
# Closest matching source for old 23 is 19 distance is 3.58
# gama09E	096	23
# gama09E	096	75	gama09Efin	096	119
# gama09E	097	12	gama09Efin	097	17
# Closest matching source for old 68 is 80 distance is 11.69
# gama09E	097	68
# Closest matching source for old 205 is 254 distance is 7.83
# gama09E	097	205
# Closest matching source for old 207 is 254 distance is 3.22
# gama09E	097	207
# Closest matching source for old 284 is 320 distance is 23.10
# gama09E	097	284
# Closest matching source for old 11 is 3 distance is 8.55
# gama09E	098	11
# gama09E	098	121	gama09Efin	098	102
# gama09E	098	123	gama09Efin	098	105
# Closest matching source for old 4 is 5 distance is 20.16
# gama09E	103	4
# Closest matching source for old 21 is 26 distance is 38.26
# gama09E	103	21
# Closest matching source for old 96 is 83 distance is 3.54
# gama09E	104	96
# Closest matching source for old 160 is 153 distance is 4.52
# gama09E	104	160
# Closest matching source for old 127 is 147 distance is 4.58
# gama09E	105	127
# gama09E	105	205	gama09Efin	105	236
# Closest matching source for old 15 is 14 distance is 10.27
# gama09F	013	15
# Closest matching source for old 30 is 27 distance is 4.22
# gama09F	013	30
# Closest matching source for old 31 is 27 distance is 4.29
# gama09F	013	31
# Closest matching source for old 32 is 28 distance is 7.40
# gama09F	013	32
# gama09F	013	44	gama09Ffin	013	37
# gama09F	013	81	gama09Ffin	013	60
# Closest matching source for old 109 is 46 distance is 9.60
# gama09F	013	109
# gama09F	013	116	gama09Ffin	013	75
# gama09F	013	154	gama09Ffin	013	100
# gama09F	013	157	gama09Ffin	013	104
# Closest matching source for old 184 is 123 distance is 23.86
# gama09F	013	184
# gama09F	013	192	gama09Ffin	013	128
# gama09F	013	196	gama09Ffin	013	134
# gama09F	014	72	gama09Ffin	014	85
# Closest matching source for old 67 is 103 distance is 12.32
# gama09F	015	67
# Closest matching source for old 257 is 260 distance is 5.63
# gama09F	015	257
# Closest matching source for old 262 is 259 distance is 14.46
# gama09F	015	262
# Closest matching source for old 47 is 48 distance is 28.29
# gama09F	016	47
# Closest matching source for old 73 is 84 distance is 16.91
# gama09F	016	73
# Closest matching source for old 118 is 81 distance is 4.58
# gama09F	021	118
# Closest matching source for old 120 is 83 distance is 26.23
# gama09F	021	120
# gama09F	021	208	gama09Ffin	021	144
# gama09F	022	73	gama09Ffin	022	95
# Closest matching source for old 117 is 168 distance is 39.41
# gama09F	022	117
# Closest matching source for old 121 is 172 distance is 46.49
# gama09F	022	121
# Closest matching source for old 55 is 96 distance is 11.64
# gama09F	024	55
# gama09F	024	64	gama09Ffin	024	126
# gama09F	025	73	gama09Ffin	025	44
# gama09F	025	86	gama09Ffin	025	56
# gama09F	027	162	gama09Ffin	027	125
# Closest matching source for old 16 is 15 distance is 16.49
# gama09F	028	16
# Closest matching source for old 159 is 76 distance is 10.08
# gama09F	028	159
# Closest matching source for old 59 is 65 distance is 3.63
# gama09F	031	59
# gama09F	031	142	gama09Ffin	031	149
# gama09F	031	177	gama09Ffin	031	180
# gama09F	031	403	gama09Ffin	031	389
# gama09F	031	425	gama09Ffin	031	406
# gama09F	031	475	gama09Ffin	031	450
# gama09F	032	52	gama09Ffin	032	43
# Closest matching source for old 46 is 41 distance is 6.85
# gama09F	033	46
# gama09F	033	85	gama09Ffin	033	80
# gama09F	034	24	gama09Ffin	034	19
# Closest matching source for old 31 is 23 distance is 11.71
# gama09F	034	31
# Closest matching source for old 36 is 27 distance is 4.82
# gama09F	034	36
# Closest matching source for old 54 is 39 distance is 4.64
# gama09F	034	54
# gama09F	034	86	gama09Ffin	034	74
# Closest matching source for old 115 is 90 distance is 11.73
# gama09F	034	115
# gama09F	035	153	gama09Ffin	035	107
# gama09F	035	183	gama09Ffin	035	126
# Closest matching source for old 330 is 210 distance is 3.38
# gama09F	035	330
# Closest matching source for old 526 is 301 distance is 16.30
# gama09F	035	526
# gama09F	035	527	gama09Ffin	035	300
# Closest matching source for old 569 is 324 distance is 8.27
# gama09F	035	569
# gama09F	035	575	gama09Ffin	035	331
# gama09F	036	78	gama09Ffin	036	92
# Closest matching source for old 96 is 111 distance is 11.01
# gama09F	036	96
# Closest matching source for old 153 is 154 distance is 25.65
# gama09F	036	153
# gama09F	036	177	gama09Ffin	036	176
# gama09F	036	195	gama09Ffin	036	194
# Closest matching source for old 205 is 202 distance is 4.24
# gama09F	036	205
# gama09F	036	261	gama09Ffin	036	236
# gama09F	036	307	gama09Ffin	036	270
# gama09F	036	342	gama09Ffin	036	303
# Closest matching source for old 60 is 50 distance is 9.72
# gama09F	037	60
# gama09F	037	154	gama09Ffin	037	117
# Closest matching source for old 202 is 143 distance is 4.26
# gama09F	037	202
# gama09F	037	217	gama09Ffin	037	154
# gama09F	037	305	gama09Ffin	037	209
# gama09F	038	271	gama09Ffin	038	200
# Closest matching source for old 283 is 207 distance is 4.09
# gama09F	038	283
# gama09F	041	3	gama09Ffin	041	1
# gama09F	041	68	gama09Ffin	041	128
# gama09F	041	81	gama09Ffin	041	145
# gama09F	041	108	gama09Ffin	041	196
# gama09F	041	134	gama09Ffin	041	245
# gama09F	041	190	gama09Ffin	041	332
# Closest matching source for old 14 is 13 distance is 25.12
# gama09F	042	14
# Closest matching source for old 58 is 44 distance is 24.42
# gama09F	042	58
# Closest matching source for old 61 is 46 distance is 24.38
# gama09F	042	61
# gama09F	042	88	gama09Ffin	042	68
# Closest matching source for old 138 is 107 distance is 3.10
# gama09F	042	138
# gama09F	043	6	gama09Ffin	043	4
# Closest matching source for old 107 is 68 distance is 16.84
# gama09F	043	107
# gama09F	043	113	gama09Ffin	043	77
# gama09F	043	196	gama09Ffin	043	139
# Closest matching source for old 241 is 176 distance is 14.16
# gama09F	043	241
# gama09F	044	43	gama09Ffin	044	33
# Closest matching source for old 100 is 67 distance is 8.63
# gama09F	044	100
# Closest matching source for old 131 is 95 distance is 3.80
# gama09F	044	131
# gama09F	045	28	gama09Ffin	045	20
# Closest matching source for old 33 is 22 distance is 5.78
# gama09F	045	33
# gama09F	045	57	gama09Ffin	045	45
# Closest matching source for old 132 is 91 distance is 7.20
# gama09F	045	132
# gama09F	045	145	gama09Ffin	045	101
# gama09F	046	21	gama09Ffin	046	18
# Closest matching source for old 192 is 118 distance is 12.07
# gama09F	046	192
# gama09F	047	76	gama09Ffin	047	84
# gama09F	047	150	gama09Ffin	047	139
# gama09F	047	221	gama09Ffin	047	195
# gama09F	047	253	gama09Ffin	047	226
# gama09F	047	264	gama09Ffin	047	234
# gama09F	048	1	gama09Ffin	048	1
# gama09F	048	6	gama09Ffin	048	6
# gama09F	048	126	gama09Ffin	048	119
# Closest matching source for old 215 is 190 distance is 12.29
# gama09F	048	215
# gama09F	048	364	gama09Ffin	048	287
# gama09F	052	60	gama09Ffin	052	54
# gama09F	052	173	gama09Ffin	052	177
# Closest matching source for old 174 is 173 distance is 3.19
# gama09F	052	174
# Closest matching source for old 8 is 9 distance is 19.19
# gama09F	053	8
# gama09F	053	25	gama09Ffin	053	35
# Closest matching source for old 56 is 76 distance is 3.34
# gama09F	053	56
# Closest matching source for old 69 is 88 distance is 9.62
# gama09F	053	69
# gama09F	053	79	gama09Ffin	053	96
# Closest matching source for old 97 is 113 distance is 5.05
# gama09F	053	97
# Closest matching source for old 102 is 118 distance is 3.14
# gama09F	053	102
# Closest matching source for old 110 is 125 distance is 6.86
# gama09F	053	110
# gama09F	053	141	gama09Ffin	053	161
# gama09F	053	170	gama09Ffin	053	209
# gama09F	053	181	gama09Ffin	053	227
# Closest matching source for old 186 is 234 distance is 4.67
# gama09F	053	186
# gama09F	062	7	gama09Ffin	062	11
# gama09F	062	33	gama09Ffin	062	51
# gama09F	062	38	gama09Ffin	062	62
# gama09F	062	47	gama09Ffin	062	76
# Closest matching source for old 53 is 92 distance is 4.96
# gama09F	062	53
# gama09F	062	61	gama09Ffin	062	105
# gama09F	062	91	gama09Ffin	062	160
# Closest matching source for old 96 is 171 distance is 12.95
# gama09F	062	96
# Closest matching source for old 103 is 177 distance is 21.51
# gama09F	062	103
# Closest matching source for old 127 is 218 distance is 18.35
# gama09F	062	127
# Closest matching source for old 129 is 218 distance is 19.97
# gama09F	062	129
# Closest matching source for old 136 is 214 distance is 24.11
# gama09F	062	136
# Closest matching source for old 166 is 276 distance is 13.07
# gama09F	062	166
# gama09F	062	170	gama09Ffin	062	282
# gama09F	062	174	gama09Ffin	062	288
# Closest matching source for old 184 is 301 distance is 17.46
# gama09F	062	184
# Closest matching source for old 3 is 3 distance is 27.17
# gama09F	063	3
# gama09F	063	27	gama09Ffin	063	23
# gama09F	063	36	gama09Ffin	063	28
# Closest matching source for old 59 is 52 distance is 17.03
# gama09F	063	59
# Closest matching source for old 67 is 56 distance is 10.52
# gama09F	063	67
# gama09F	067	16	gama09Ffin	067	9
# gama09F	067	30	gama09Ffin	067	19
# gama09F	067	38	gama09Ffin	067	28
# gama09F	067	39	gama09Ffin	067	29
# Closest matching source for old 45 is 31 distance is 3.56
# gama09F	067	45
# Closest matching source for old 54 is 35 distance is 9.62
# gama09F	067	54
# gama09F	067	66	gama09Ffin	067	48
# Closest matching source for old 92 is 69 distance is 8.68
# gama09F	067	92
# gama09F	067	94	gama09Ffin	067	65
# gama09F	067	108	gama09Ffin	067	78
# gama09F	067	122	gama09Ffin	067	93
# gama09F	067	145	gama09Ffin	067	110
# Closest matching source for old 163 is 122 distance is 4.11
# gama09F	067	163
# Closest matching source for old 175 is 134 distance is 18.24
# gama09F	067	175
# Closest matching source for old 209 is 158 distance is 13.01
# gama09F	067	209
# gama09F	067	218	gama09Ffin	067	164
# gama09F	067	231	gama09Ffin	067	168
# gama09F	067	253	gama09Ffin	067	180
# gama09F	067	511	gama09Ffin	067	293
# Closest matching source for old 73 is 91 distance is 12.77
# gama09F	068	73
# gama09F	068	75	gama09Ffin	068	95
# gama09F	068	113	gama09Ffin	068	141
# gama09F	068	220	gama09Ffin	068	260
# gama09F	068	288	gama09Ffin	068	350
# Closest matching source for old 4 is 3 distance is 13.81
# gama09F	071	4
# Closest matching source for old 6 is 2 distance is 5.69
# gama09F	071	6
# Closest matching source for old 13 is 9 distance is 11.14
# gama09F	071	13
# Closest matching source for old 23 is 24 distance is 17.75
# gama09F	071	23
# Closest matching source for old 29 is 24 distance is 11.91
# gama09F	071	29
# gama09F	072	5	gama09Ffin	072	6
# gama09F	072	35	gama09Ffin	072	35
# gama09F	072	163	gama09Ffin	072	137
# gama09F	072	244	gama09Ffin	072	197
# Closest matching source for old 19 is 20 distance is 8.15
# gama09F	073	19
# Closest matching source for old 107 is 89 distance is 3.64
# gama09F	073	107
# gama09F	074	23	gama09Ffin	074	15
# gama09F	074	24	gama09Ffin	074	16
# Closest matching source for old 23 is 12 distance is 17.28
# gama09F	076	23
# gama09F	077	195	gama09Ffin	077	195
# gama09F	077	199	gama09Ffin	077	199
# gama09F	077	210	gama09Ffin	077	210
# gama09F	077	247	gama09Ffin	077	247
# Closest matching source for old 52 is 52 distance is 6.93
# gama09F	079	52
# Closest matching source for old 25 is 27 distance is 6.87
# gama09F	082	25
# gama09F	082	77	gama09Ffin	082	74
# Closest matching source for old 234 is 202 distance is 14.61
# gama09F	082	234
# gama09F	082	235	gama09Ffin	082	205
# gama09F	083	152	gama09Ffin	083	99
# gama09F	084	12	gama09Ffin	084	11
# gama09F	084	77	gama09Ffin	084	68
# Closest matching source for old 135 is 118 distance is 3.66
# gama09F	084	135
# gama09F	084	219	gama09Ffin	084	175
# gama09F	085	93	gama09Ffin	085	75
# gama09F	085	227	gama09Ffin	085	178
# gama09F	085	240	gama09Ffin	085	192
# gama09F	085	255	gama09Ffin	085	202
# Closest matching source for old 6 is 8 distance is 9.57
# gama09F	086	6
# gama09F	086	142	gama09Ffin	086	121
# Closest matching source for old 60 is 57 distance is 3.88
# gama09F	087	60
# gama09F	087	97	gama09Ffin	087	96
# gama09F	087	110	gama09Ffin	087	109
# Closest matching source for old 272 is 282 distance is 10.87
# gama09F	087	272
# gama09F	087	274	gama09Ffin	087	281
# gama09F	087	326	gama09Ffin	087	316
# Closest matching source for old 344 is 333 distance is 9.91
# gama09F	087	344
# Closest matching source for old 383 is 361 distance is 8.52
# gama09F	087	383
# Closest matching source for old 389 is 347 distance is 4.07
# gama09F	087	389
# Closest matching source for old 409 is 392 distance is 5.08
# gama09F	087	409
# gama09F	087	427	gama09Ffin	087	404
# gama09F	087	462	gama09Ffin	087	436
# Closest matching source for old 3 is 7 distance is 6.37
# gama09F	088	3
# gama09F	088	136	gama09Ffin	088	172
# Closest matching source for old 454 is 462 distance is 12.67
# gama09F	088	454
# Closest matching source for old 42 is 32 distance is 5.87
# gama09F	091	42
# Closest matching source for old 55 is 47 distance is 16.76
# gama09F	091	55
# Closest matching source for old 59 is 47 distance is 10.10
# gama09F	091	59
# gama09F	091	83	gama09Ffin	091	66
# Closest matching source for old 91 is 70 distance is 28.31
# gama09F	091	91
# Closest matching source for old 121 is 110 distance is 3.12
# gama09F	091	121
# gama09F	091	125	gama09Ffin	091	112
# Closest matching source for old 131 is 114 distance is 20.79
# gama09F	091	131
# Closest matching source for old 179 is 141 distance is 12.63
# gama09F	091	179
# Closest matching source for old 182 is 144 distance is 15.63
# gama09F	091	182
# Closest matching source for old 54 is 40 distance is 14.55
# gama09F	092	54
# Closest matching source for old 78 is 66 distance is 9.02
# gama09F	092	78
# gama09F	093	198	gama09Ffin	093	171
# Closest matching source for old 82 is 43 distance is 13.32
# gama09F	094	82
# gama09F	094	140	gama09Ffin	094	84
# Closest matching source for old 198 is 134 distance is 8.33
# gama09F	094	198
# gama09F	095	37	gama09Ffin	095	37
# gama09F	095	40	gama09Ffin	095	40
# gama09F	095	48	gama09Ffin	095	48
# gama09F	095	162	gama09Ffin	095	162
# gama09F	095	176	gama09Ffin	095	176
# gama09F	095	183	gama09Ffin	095	183
# gama09F	095	188	gama09Ffin	095	188
# gama09F	095	208	gama09Ffin	095	208
# gama09F	095	267	gama09Ffin	095	267
# gama09F	095	270	gama09Ffin	095	270
# gama09F	095	273	gama09Ffin	095	273
# gama09F	095	284	gama09Ffin	095	284
# Closest matching source for old 7 is 1 distance is 8.79
# gama09F	096	7
# gama09F	096	15	gama09Ffin	096	14
# gama09F	096	23	gama09Ffin	096	25
# gama09F	096	41	gama09Ffin	096	49
# gama09F	096	59	gama09Ffin	096	71
# gama09F	096	80	gama09Ffin	096	100
# gama09F	096	87	gama09Ffin	096	111
# Closest matching source for old 141 is 159 distance is 7.22
# gama09F	096	141
# gama09F	096	165	gama09Ffin	096	187
# Closest matching source for old 219 is 240 distance is 5.11
# gama09F	096	219
# Closest matching source for old 257 is 287 distance is 4.20
# gama09F	096	257
# gama09F	096	274	gama09Ffin	096	307
# gama09F	096	304	gama09Ffin	096	340
# gama09F	096	405	gama09Ffin	096	468
# Closest matching source for old 137 is 132 distance is 14.35
# gama09F	097	137
# gama09F	097	217	gama09Ffin	097	203
# gama09F	097	218	gama09Ffin	097	200
# gama09F	097	282	gama09Ffin	097	264
# gama09F	097	316	gama09Ffin	097	291
# Closest matching source for old 348 is 313 distance is 4.78
# gama09F	097	348
# Closest matching source for old 122 is 93 distance is 5.08
# gama09F	098	122
# Closest matching source for old 176 is 135 distance is 4.27
# gama09F	098	176
# gama09F	098	199	gama09Ffin	098	158
# gama09F	098	284	gama09Ffin	098	243
# gama09F	098	301	gama09Ffin	098	255
# Closest matching source for old 317 is 272 distance is 3.92
# gama09F	098	317
# Closest matching source for old 366 is 305 distance is 7.04
# gama09F	098	366
# gama09F	098	379	gama09Ffin	098	330
# Closest matching source for old 384 is 334 distance is 5.00
# gama09F	098	384
# gama09F	098	403	gama09Ffin	098	347
# Closest matching source for old 405 is 345 distance is 12.81
# gama09F	098	405
# Closest matching source for old 8 is 6 distance is 3.90
# gama09F	103	8
# Closest matching source for old 12 is 5 distance is 4.42
# gama09F	103	12
# Closest matching source for old 20 is 17 distance is 6.42
# gama09F	103	20
# gama09F	103	71	gama09Ffin	103	45
# Closest matching source for old 79 is 49 distance is 4.41
# gama09F	103	79
# Closest matching source for old 96 is 56 distance is 7.57
# gama09F	103	96
# Closest matching source for old 113 is 64 distance is 4.87
# gama09F	103	113
# Closest matching source for old 118 is 65 distance is 4.36
# gama09F	103	118
# Closest matching source for old 119 is 61 distance is 13.61
# gama09F	103	119
# Closest matching source for old 121 is 65 distance is 3.52
# gama09F	103	121
# gama09F	104	190	gama09Ffin	104	114
# gama09F	106	34	gama09Ffin	106	15
# gama09F	106	77	gama09Ffin	106	49
# gama09F	106	112	gama09Ffin	106	79

# %%
ix
# Out:
# 18

# %%
r['field']
# Out:
# 'gama09E'

# %%
    if np.sum(ii) == 0:
        continue

    jj  = tnew['field'] == field + 'fin'
    jj *= tnew['ifu']   == ifu


    X = np.array( [told['x_com'][ii], told['z_com'][ii], told['z_com'][ii]] ).T
    Y = np.array( [tnew['x_com'][jj], tnew['z_com'][jj], tnew['z_com'][jj]] ).T

    C = np.vstack([X,Y])
    IX = np.array( [False] * len(X) + [True] * len(Y) )

    # build kdtree for combind list of objects
    tree = KDTree( C , leaf_size=2)              # doctest: +SKIP

    # find all neighbors of first object within r = .3
    ind = tree.query_radius(X[:1], r=0.3)
    #print(ind[0])

    # determine wich of these belong to the second catalog
    # on only print these
    #print(ind[0][ IX[ ind[0] ] ] )


    # now do all

    # find all neighbors of all objects within r = .3
    ind = tree.query_radius(X, r=1.)
    #print(ind[0])

    # determine which of these belong to the second catalog
    # on only print these
    for j in range(len(X)):
        # puh, this needs some explanation
        # j is the index to the current object in the X
        #  catalog
        # ind[j] contains indices to all neighbors in the combined catalog
        # IX is true only for objects in the combined catalog C that stem from Y
        # hence ind[j][ IX[ ind[j] are indices for all objects from Y
        # that are neighbors to the current object j
        # finally C[ ind[j][ IX[ ind[j] ] ]] are the coordinates
        # from the combined catalog, that are neighbors, but only showing
        # those that stem from Y.
        #print("{}:".format(j), C[ ind[j][ IX[ ind[j] ] ]])
        rold = told[ii][j]
        ix = ind[j][ IX[ ind[j] ] ] - np.sum(ii)
        if len(ix) != 1:
            print("{} {}".format(rold['id'],  "-"))
        else:
            rnew = tnew[jj][ind[j][ IX[ ind[j] ] ] - np.sum(ii)][0]
            print("#{}: {} {} {} -> {}: {} {} {}".format(rold['id'], rold['x_com'], rold['y_com'], rold['z_com'],  rnew['id'], rnew['x_com'], rnew['y_com'], rnew['z_com']))
# Out:
# 81 -
# 8 -
# 10 -
# 53 -
# 135 -
# 143 -
# 28 -
# 68 -
# 131 -
# 189 -
# 2 -
# 22 -
# 30 -
# 67 -
# 137 -
# 8 -
# 7 -
# 44 -
# 54 -
# 81 -
# 8 -
# 10 -
# 53 -
# 135 -
# 143 -
# 6 -
# 8 -
# 8 -
# 17 -
# 195 -

# %%
r
# Out:
# <Row index=0>
#   col1   col2  col3
#   str7  int64 int64
# ------- ----- -----
# gama09E    14    81

# %%
for field in fields:
    for ifu in ifus[field]:
        
        
        print("field {} ifu {}".format(field, ifu))
        ii  = told['field'] == field.replace("fin","")
        ii *= told['ifu']   == ifu
        if np.sum(ii) == 0:
            continue

        jj  = tnew['field'] == field
        jj *= tnew['ifu']   == ifu
        
        
        X = np.array( [told['x_com'][ii], told['z_com'][ii], told['z_com'][ii]] ).T
        Y = np.array( [tnew['x_com'][jj], tnew['z_com'][jj], tnew['z_com'][jj]] ).T
        
        C = np.vstack([X,Y])
        IX = np.array( [False] * len(X) + [True] * len(Y) )

        # build kdtree for combind list of objects
        tree = KDTree( C , leaf_size=2)              # doctest: +SKIP

        # find all neighbors of first object within r = .3
        ind = tree.query_radius(X[:1], r=0.3)
        #print(ind[0])

        # determine wich of these belong to the second catalog
        # on only print these
        #print(ind[0][ IX[ ind[0] ] ] )


        # now do all

        # find all neighbors of all objects within r = .3
        ind = tree.query_radius(X, r=1.)
        #print(ind[0])

        # determine which of these belong to the second catalog
        # on only print these
        for j in range(len(X)):
            # puh, this needs some explanation
            # j is the index to the current object in the X
            #  catalog
            # ind[j] contains indices to all neighbors in the combined catalog
            # IX is true only for objects in the combined catalog C that stem from Y
            # hence ind[j][ IX[ ind[j] are indices for all objects from Y
            # that are neighbors to the current object j
            # finally C[ ind[j][ IX[ ind[j] ] ]] are the coordinates
            # from the combined catalog, that are neighbors, but only showing
            # those that stem from Y.
            #print("{}:".format(j), C[ ind[j][ IX[ ind[j] ] ]])
            rold = told[ii][j]
            ix = ind[j][ IX[ ind[j] ] ] - np.sum(ii)
            if len(ix) != 1:
                print("{} {}".format(rold['id'],  "-"))
            else:
                rnew = tnew[jj][ind[j][ IX[ ind[j] ] ] - np.sum(ii)][0]
                print("#{}: {} {} {} -> {}: {} {} {}".format(rold['id'], rold['x_com'], rold['y_com'], rold['z_com'],  rnew['id'], rnew['x_com'], rnew['y_com'], rnew['z_com']))
            
            
        1/0
# Out:
# field gama09Efin ifu 013
# 1 -
# 2: 17.15 77.24 21.21 -> 1: 17.22 77.63 21.17
# 3 -
# 4 -
# 5: 24.94 45.37 34.84 -> 4: 24.75 45.94 34.87
# 6 -
# 7 -
# 8 -
# 9 -
# 10: 71.27 93.68 91.7 -> 10: 71.29 93.79 91.69
# 11: 88.85 4.01 91.01 -> 11: 88.58 4.89 90.69
# 12 -
# 13: 124.37 96.96 133.1 -> 17: 124.99 97.84 133.19
# 14: 84.81 1.4 140.4 -> 21: 84.77 1.56 140.55
# 15 -
# 16 -
# 17: 27.67 93.29 166.5 -> 23: 27.77 93.5 166.95
# 18 -
# 19 -
# 20: 8.75 55.03 180.7 -> 27: 8.96 55.05 180.4
# 21: 87.43 0.72 189.1 -> 28: 87.29 0.7 189.33
# 22 -
# 23: 48.6 28.35 214.77 -> 35: 48.77 28.29 214.75
# 24: 58.68 64.52 215.22 -> 34: 58.9 65.0 215.35
# 25 -
# 26 -
# 27: 9.35 63.69 220.88 -> 39: 9.26 63.94 221.13
# 28 -
# 29 -
# 30: 55.36 135.74 249.47 -> 44: 55.29 135.76 249.48
# 31: 46.69 29.97 260.56 -> 46: 46.91 29.98 260.65
# 32 -
# 33: 86.41 1.23 278.07 -> 51: 85.99 1.1 278.12
# 34: 44.32 119.88 284.64 -> 53: 44.44 120.0 285.15
# 35: 56.58 100.33 287.29 -> 54: 56.47 100.09 287.06
# 36 -
# 37 -
# 38 -
# 39 -
# 40 -
# 41 -
# 42: 131.5 77.23 328.02 -> 64: 132.1 76.83 328.22
# 43 -
# 44 -
# 45 -
# 46: 53.94 25.44 348.79 -> 67: 54.25 25.26 348.74
# 47 -
# 48 -
# 49 -
# 50 -
# 51 -
# 52 -
# 53: 84.0 0.41 433.49 -> 73: 84.3 0.14 434.08
# 54 -
# 55: 43.17 118.28 463.44 -> 76: 43.28 118.87 463.93
# 56 -
# 57: 87.4 47.63 501.87 -> 83: 87.37 48.01 501.8
# 58: 103.5 109.35 505.79 -> 84: 103.86 110.33 505.23
# 59: 84.19 1.64 521.26 -> 87: 83.98 2.17 520.88
# 60 -
# 61 -
# 62: 87.2 0.62 556.44 -> 92: 87.29 0.37 556.44
# 63 -
# 64: 55.87 81.87 568.22 -> 94: 55.45 82.22 567.9
# 65 -
# 66 -
# 67: 40.7 33.23 587.13 -> 98: 40.52 33.58 587.13
# 68: 102.79 109.53 593.6 -> 100: 103.45 109.74 593.79
# 69 -
# 70 -
# 71: 90.87 36.93 625.96 -> 104: 90.87 36.77 625.79
# 72: 103.51 109.81 631.01 -> 105: 103.66 110.67 630.32
# 73 -
# 74 -
# 75 -
# 76: 24.98 89.32 678.54 -> 112: 24.72 89.09 678.37
# 77: 103.97 109.03 689.82 -> 117: 104.1 110.66 690.5
# 78: 84.0 0.39 691.31 -> 118: 84.09 0.79 691.25
# 79 -
# 80 -
# 81: 85.2 4.07 717.49 -> 122: 84.76 4.38 717.7
# 82: 86.71 0.93 728.41 -> 124: 86.81 1.38 728.6
# 83 -
# 84 -
# 85 -
# 86 -
# 87 -
# 88: 86.42 2.54 783.25 -> 130: 87.14 3.86 783.28
# 89 -
# 90: 84.35 0.86 793.66 -> 134: 84.21 0.64 793.01
# 91: 44.76 31.04 792.68 -> 133: 44.74 30.96 793.2
# 92 -
# 93: 87.35 0.81 803.35 -> 136: 86.67 1.22 803.23
# 94 -
# 95: 86.64 0.89 830.63 -> 140: 86.68 0.92 830.78
# 96 -
# 97 -
# 98 -
# 99 -
# 100: 9.9 65.32 906.77 -> 146: 9.71 65.45 906.45
# 101 -
# 102 -
# 103: 87.73 0.72 961.18 -> 155: 86.77 0.61 961.0
# 104 -
# 105 -
# 106: 88.59 0.28 987.81 -> 158: 87.73 0.25 987.51
# 107 -
# 108 -
# 109 -
# 110 -
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_20847/2531674450.py in <module>
#      58
#      59
# ---> 60         1/0
#
# ZeroDivisionError: division by zero

# %%
print(rnew['id'][0])
# Out:
# 140

# %%
len(told[ii])
# Out:
# 110

# %%
from sklearn.neighbors import KDTree
import numpy as np

if True:
    rng = np.random.RandomState(0)
    X = rng.random_sample((10, 3))  # 10 points in 3 dimensions
    Y = rng.random_sample((10, 3))  # 10 points in 3 dimensions
    C = np.vstack([X,Y])
    IX = np.array( [False] * len(X) + [True] * len(Y) )

    # build kdtree for combind list of objects
    tree = KDTree( C , leaf_size=2)              # doctest: +SKIP

    # find all neighbors of first object within r = .3
    ind = tree.query_radius(X[:1], r=0.3)
    #print(ind[0])

    # determine wich of these belong to the second catalog
    # on only print these
    #print(ind[0][ IX[ ind[0] ] ] )


    # now do all

    # find all neighbors of all objects within r = .3
    ind = tree.query_radius(X, r=0.3)
    #print(ind[0])

    # determine which of these belong to the second catalog
    # on only print these
    for j in range(len(X)):
        # puh, this needs some explanation
        # j is the index to the current object in the X
        #  catalog
        # ind[j] contains indices to all neighbors in the combined catalog
        # IX is true only for objects in the combined catalog C that stem from Y
        # hence ind[j][ IX[ ind[j] are indices for all objects from Y
        # that are neighbors to the current object j
        # finally C[ ind[j][ IX[ ind[j] ] ]] are the coordinates
        # from the combined catalog, that are neighbors, but only showing
        # those that stem from Y.
        print("{}:".format(j), C[ ind[j][ IX[ ind[j] ] ]])
# Out:
# 0: []
# 1: [[0.31542835 0.36371077 0.57019677]
#  [0.6818203  0.3595079  0.43703195]]
# 2: []
# 3: [[0.26455561 0.77423369 0.45615033]]
# 4: [[0.43860151 0.98837384 0.10204481]]
# 5: [[0.20887676 0.16130952 0.65310833]]
# 6: []
# 7: [[0.61209572 0.616934   0.94374808]]
# 8: [[0.2532916  0.46631077 0.24442559]]
# 9: []

# %%
from astropy.coordinates import SkyCoord
from astropy import units as u


for field in fields:
    for ifu in ifus[field]:
        ii  = told['field'] == field.replace("fin","")
        ii *= told['ifu']   == ifu
        if np.sum(ii) == 0:
            continue

        jj  = tnew['field'] == field
        jj *= tnew['ifu']   == ifu

        c_old = SkyCoord(ra=np.array(told['ra_com'][ii],dtype=float)*u.degree, dec=np.array(told['dec_com'][ii],dtype=float)*u.degree, 
                     distance=np.array(told['wl_com'][ii],dtype=float)*u.kpc)
        
        c_new = SkyCoord(ra=np.array(tnew['ra_com'][jj],dtype=float)*u.degree, dec=np.array(tnew['dec_com'][jj],dtype=float)*u.degree, 
                     distance=np.array(tnew['wl_com'][jj],dtype=float)*u.kpc)
        

        #1/0
        idx, d2d, d3d = c_old.match_to_catalog_sky(c_new)

        
        from sklearn.neighbors import KDTree
        import numpy as np

        if False:
            rng = np.random.RandomState(0)
            X = rng.random_sample((10, 2))  # 10 points in 2 dimensions
            Y = rng.random_sample((10, 2))  # 10 points in 2 dimensions
            C = np.vstack([X,Y])
            IX = np.array( [False] * len(X) + [True] * len(Y) )

            # build kdtree for combind list of objects
            tree = KDTree( C , leaf_size=2)              # doctest: +SKIP

            # find all neighbors of first object within r = .3
            ind = tree.query_radius(X[:1], r=0.3)
            #print(ind[0])

            # determine wich of these belong to the second catalog
            # on only print these
            #print(ind[0][ IX[ ind[0] ] ] )


            # now do all

            # find all neighbors of all objects within r = .3
            ind = tree.query_radius(X, r=0.3)
            #print(ind[0])

            # determine which of these belong to the second catalog
            # on only print these
            for j in range(len(X)):
                # puh, this needs some explanation
                # j is the index to the current object in the X
                #  catalog
                # ind[j] contains indices to all neighbors in the combined catalog
                # IX is true only for objects in the combined catalog C that stem from Y
                # hence ind[j][ IX[ ind[j] are indices for all objects from Y
                # that are neighbors to the current object j
                # finally C[ ind[j][ IX[ ind[j] ] ]] are the coordinates
                # from the combined catalog, that are neighbors, but only showing
                # those that stem from Y.
                print("{}:".format(j), C[ ind[j][ IX[ ind[j] ] ]])
        
        
        
        
        



#c = SkyCoord(ra=ra1*u.degree, dec=dec1*u.degree, distance=distance1*u.kpc)
#catalog = SkyCoord(ra=ra2*u.degree, dec=dec2*u.degree, distance=distance2*u.kpc)
#idx, d2d, d3d = c.match_to_catalog_3d(catalog)

# %%
len(c_old)
# Out:
# 160

# %%
len(d3d)
# Out:
# 160
