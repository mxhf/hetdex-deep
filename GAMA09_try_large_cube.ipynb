# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Batch cube stacking

# %%
# %matplotlib inline
import sys
import os
import os.path
import subprocess
import numpy as np

import tables as tb
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from astropy.visualization import ZScaleInterval

# %%
# this is so that in "compute" all imports are found
sys.path.append("/home/idies/workspace/Storage/mxhf/persistent/mygama09")

# %%
from hetdex_api.shot import *

# %% [markdown]
# # Cube stacking code

# %%
COMMANDLINE = False

# %%
# coding: utf-8
from __future__ import print_function

import pylab
from astropy.io import fits
import sys

from scipy import optimize
import spectrum
import numpy
import optparse
import PolygonIntersect
from matplotlib import pyplot as plt
import spectrum
from astropy.io import ascii
from astropy.table import Table
import os
import glob
import numpy as np

from scipy.interpolate import UnivariateSpline

import sys
from astropy.table import Column, vstack
from astropy.io import ascii

import pickle

from astropy.table import Table
import tables as tb


def circle(x,y,size):
        tt = np.arange(0.,2.*np.pi, np.pi/18.)
        xx = size/2. * np.cos(tt) + x
        yy = size/2. * np.sin(tt) + y
        return xx,yy

def pixel(x,y,size):
    xx,yy=[],[]
    xx.append(x-size/2.)
    yy.append(y-size/2.)

    xx.append(x+size/2.)
    yy.append(y-size/2.)

    xx.append(x+size/2.)
    yy.append(y+size/2.)

    xx.append(x-size/2.)
    yy.append(y+size/2.)

    return xx,yy

def create_3D_header(xc, yc, rad, decd, pixelsize,start,step):
    h = fits.Header()
    #h.update("WCSDIM  ", 3, "");
    #h.update("WAT0_001", "system=image", "");
    h["CTYPE3"] = "Wave"
    h["CRPIX3"] = 1.
    h["CRVAL3"] = start
    h["CDELT3"] = step
    #h["WAT1_001"] = wtype=tan
    h["CTYPE1"] = "RA---TAN"
    h["CRPIX1"] = xc
    h["CRVAL1"] = rad
    h["CDELT1"] = - pixelsize/3600.
    h["CUNIT1"] = "deg"
    #h["WAT2_001"] = wtype=tan
    h["CTYPE2"] = "DEC--TAN"
    h["CRPIX2"] = yc
    h["CRVAL2"] = decd
    h["CDELT2"] = pixelsize/3600.
    h["CUNIT2"] = "deg"
    return h

def create_2D_header(xc, yc, rad, decd, pixelsize):
    h = fits.Header()
    #h.update("WAT1_001", "wtype=tan axtype=ra", "");
    h["CTYPE1"] = "RA--TAN"
    h["CRPIX1"] = xc
    h["CRVAL1"] = "rad"
    h["CDELT1"] = - pixelsize/3600.
    h["CUNIT1"] = "deg"
    #h["WAT2_001"] = wtype=tan
    h["CTYPE2"] = "DEC--TAN"
    h["CRPIX2"] = yc
    h["CRVAL2"] = decd
    h["CDELT2"] = pixelsize/3600.
    h["CUNIT2"] = "deg"
    return h

def create_I_header():
    h = fits.Header()
    #h.update("WAT1_001", "wtype=tan axtype=ra", "");
    h["CTYPE1"] = "pixel"
    h["CRPIX1"] = 1
    h["CRVAL1"] = 1.
    h["CDELT1"] = 1.
    h["CUNIT1"] = "px"
    #h["WAT2_001"] = wtype=tan
    h["CTYPE2"] = "fiber"
    h["CRPIX2"] = 1
    h["CRVAL2"] = 1.
    h["CDELT2"] = 1.
    h["CUNIT2"] = "fib"
    return h

def tan_dir_sci(RA0, DEC0, PA0, RA,DEC, quiet=True):
    """
    Calculates pixel positions in the IFU for a given set of RA and DEC coordinates.

    Input

    IFU_RA0, IFU_DEC0 = IFU zero coordinates (in deg)
    RA, DEC = 1D arrays of RA and DEC coordinates
    astrom_terms = parameters for the astrometric solution
    quiet = Boolean, disable output (standard: False)

    Returns:
    pixx, pixy = two 1D arrays containing x and y coordinates (in deg!) for the given RAs and DECs
    """
    if not quiet: print("IFU_RA0, IFU_DEC0 = {},{}".format( IFU_RA0, IFU_DEC0) )

    rRA0  = RA0*np.pi/180.
    rDEC0  = DEC0*np.pi/180.

    rPA0 = PA0*np.pi/180.

    if not quiet: print("[tan_dir_sci] IFU_RA0, IFU_DEC0 = {},{}".format( IFU_RA0, IFU_DEC0 ) )

    rRA = RA*np.pi/180.

    rDEC = DEC*np.pi/180.

    if not quiet: print("[tan_dir_gui] rRA, rDEC: {}, {}".format( rRA, rDEC ) )

    # eq 9 in Greisen AIPSMEMO27
    L = np.cos(rDEC)*np.sin(rRA - rRA0)/  (np.sin(rDEC)*np.sin(rDEC0) + np.cos(rDEC)*np.cos(rDEC0)*np.cos(rRA - rRA0))

    M = (np.sin(rDEC)*np.cos(rDEC0) - np.cos(rDEC)*np.sin(rDEC0)*np.cos(rRA - rRA0))/(np.sin(rDEC)*        
                                                np.sin(rDEC0) + np.cos(rDEC)*np.cos(rDEC0)*np.cos(rRA - rRA0))

    # eq 5 in Greisen AIPSMEMO27
    pixx = L*np.cos(rPA0) + M*np.sin(rPA0)
    pixy = M*np.cos(rPA0) - L*np.sin(rPA0)

    return - pixx/np.pi*180.*3600., pixy/np.pi*180.*3600.


def findZeroPixRaDec(x,y, RA0, DEC0):
    """
    Find RA and DEC coordinates that correspond to the given
    pixel coordinates.
    We do this here the cheap way. We use a nonlinear fit 
    rather than working out the inverse transformation.
    """
    def peval(p,RA0, DEC0):
        RA,DEC = p
        return tan_dir_sci(RA0, DEC0, 0., RA, DEC, quiet=True)

    def resid(p,x,y,RA0, DEC0):
        xt,yt = peval(p,RA0, DEC0)
        return (xt-x), (yt-y)

    p0 = [RA0,DEC0]
    bestfit = optimize.leastsq(resid, p0, args=(x,y,RA0,DEC0) )
    return bestfit[0]

def hms2deg(hms):
    tt = hms.split(":")
    h,m,s = float(tt[0]), float(tt[1]), float(tt[2])
    return h*15. + m/4. + s/240.

def dms2deg(dms):
    tt = dms.split(":")
    d,m,s = float(tt[0]), float(tt[1]), float(tt[2])
    return d + m/60. + s/3600.

# %%
if COMMANDLINE:
    import argparse

    parser = argparse.ArgumentParser(description='Build a hetdex cube.')
    #parser.add_argument('--basepath', default="/work/03946/hetdex/maverick/red1/reductions")
    parser.add_argument('--basepath', default="../reductions")
    parser.add_argument('--pa', type=float, default=0.,
                                help='Position angle for cube.')

    parser.add_argument('--write_single_cubes', action="store_true",
                                help='Write individual per-shot cubes before median stacking.')

    parser.add_argument('--norm_smoothing', type=float, default=0.005,
                                help='Smoothing for cross IFU and cross exposure fiber to fiber normalisation (default 0.05)')

    parser.add_argument('--ifuslot', type=str, default = "022", nargs='+', metavar='SLOTS',
            help='IFUslot to create cube for, can pass multiple. ')
    
    parser.add_argument('--shotlist', type=str,
                                help='List of actual shots to use.')

    args = parser.parse_args()

    pa=args.pa
    fiberpos = args.dither_use
    ifuslot = args.ifuslot
    basepath = args.basepath
    shotlist = args.shotlist
    write_single_cubes = args.write_single_cubes
    
    
prefix = ""
extensions = ["sky_subtracted", "sky_spectrum", "fiber_to_fiber"]

# read dithall.use
filebase = {}

exposure_times = []

sky_spectra = [] # holds for each fiber spectrum
                 # the corresponing amplifier wide sky (median accorss all fibers after correcting for fiber_to_fiber)
    
# generic remedy virus wavelength grid
wlgrid = np.arange( 1036 ) * 2. + 3470.
wlstart, wlstop = wlgrid[0], wlgrid[-1]
        


fid = -1

# %% [markdown]
# ## Loading all spectra for all IFUs in all shots that we plan to combine into a cube here

# %%
def load_data(basepath, shotlist, ifuslots):
    names = ["count", "amplifier", "fiberid", "ra", "dec", "shot", "night", "shotid", "exp"]
    dtype = [int, 'U2', int, float, float, 'U12', 'U8', 'U3', float]
    fibers = Table(names=names, dtype=dtype)

    spectra = {}
    allspec = []

    count = 0
    for shot in shotlist:
        print("Loading shot {}".format(shot))
        hdf5_filename = '{}.h5'.format(shot)
        if not os.path.exists(os.path.join(basepath, hdf5_filename)):
            print("ERROR: File {} does not exist".format(os.path.join(basepath,hdf5_filename)))
            continue
        hdf5file = tb.open_file(os.path.join(basepath,hdf5_filename) )

        h5fibers = hdf5file.root.Fibers
        h5info   = hdf5file.root.Info

        t = Table(h5info.read())

        ifiber = np.arange(len(h5fibers))

        uifus = np.unique( t["ifuslot"] ).tolist()

        for ifu in ifuslots:
            if not int(ifu) in uifus:
                print("WARNING: Shot {} contains no data for IFU slot {}".format(shot, ifu))
                continue
            print("  IFU slot {}".format(ifu))
            # find all spectra that belong to current IFU
            ii = t["ifuslot"] == int(ifu)
            s = []
            for i in ifiber[ii]:
                x,y = t["ra"][i], t["dec"][i]
                allspec.append( h5fibers[i]["spectrum"]  )


                amplifier = ""
                night = shot[:8]
                shotid = shot[9:]
                fibers.add_row([count, amplifier, i, x,y, shot, night, shotid, 0 ])

        print("len(allspec): ", len(allspec))
        print("len(fibers): ", len(fibers))

    allspec = np.array(allspec)
    allspec[np.isnan(allspec)] = 0.
    print("Done.")
    
    return fibers, allspec

# fibers, allspec = load_data(shotlist, ifuslots)

# %% [markdown]
# ## determine a pixel grid

# %%
def find_pixel_grid(fibers, RA0=None, DEC0=None, nx = None, ny = None, PLOT = False):
    
    if RA0 == None or DEC0 == None:
        RA0, DEC0 = numpy.mean(fibers["ra"]), numpy.mean(fibers["dec"])
    print("Set tangent point for projection to RA0 = %.6f and DEC0  = %.6f." % (RA0, DEC0)) 

    fxx,fyy = tan_dir_sci(RA0, DEC0, pa, fibers["ra"], fibers["dec"], quiet=True)


    maxx = max(fxx)+FIBERD/2.
    maxy = max(fyy)+FIBERD/2.
    minx = min(fxx)-FIBERD/2.
    miny = min(fyy)-FIBERD/2.

    print("Extent in RA : {:.1f} \"".format(maxx-minx))
    print("Extent in Dec : {:.1f} \"".format(maxy-miny))

    if nx == None or ny == None:
        # Automatically determine pixel gridsize
        nx = int( round( ( maxx - minx ) / pixelsize ))
        ny = int( round( ( maxy - miny ) / pixelsize ))
        # create list of all pixel center coordinates 
        xx=np.arange(nx)*pixelsize + minx + pixelsize/2.
        yy=np.arange(ny)*pixelsize + miny + pixelsize/2.
    else:
        # use user-defined grid insted
        xx=np.arange(nx)-(nx-1.)/2.
        yy=np.arange(ny)-(ny-1.)/2.
        xx *= pixelsize
        yy *= pixelsize

    X,Y=np.meshgrid(xx,yy)
    pixels = np.zeros( [ len(X.flatten()) ,3]  ) 
    pixels[:,0] = np.arange(len(pixels))
    pixels[:,1] = X.flatten()
    pixels[:,2] = Y.flatten()

    PLOT = False
    if PLOT:
        # plotting
        s = plt.subplot() 
        #for p in pixels:
            #    xx,yy = pixel(p[1],p[2], pixelsize)
        #    s.fill( xx, yy, facecolor='none',linewidth=0.2 )

        for f in zip( fxx,fyy ):
            xx,yy = circle(f[0],f[1], FIBERD)
            s.fill( xx, yy, facecolor='none',linewidth=0.2,edgecolor='blue' )

        s.set_xlabel("x (\")")
        s.set_ylabel("y (\")")
        s.axis('equal')
        
    return pixels,xx,yy,X,Y,fxx,fyy,nx,ny, RA0, DEC0

# %% [markdown]
# ## calculate pixel/fiber intersections

# %%
import multiprocessing
from joblib import Parallel, delayed

num_cores = multiprocessing.cpu_count()
print("Have {} cores.".format(num_cores))
# Out:
# Have 8 cores.

# %%
from time import sleep

# %%
def test(shotlist, MULTIPROCESSING):
    def worker(shot, idx, status):
        for i in range(10):
            status[idx] = i
            sleep(1)
            
    status = [0] * len(shotlist)
        
    jobs = []
    
    for idx, shot in enumerate( shotlist ):
        print("Launching shot {}".format(shot))

        jj = fibers["shot"] == shot
        shotfibers = fibers[jj]
        shotfxx = fxx[jj]
        shotfyy = fyy[jj]
    
        if MULTIPROCESSING:
            p = multiprocessing.Process(target=worker, args=(shot, idx, status))
            jobs.append(p)
            p.start()
        else:
            worker(shot, idx, status)

    if MULTIPROCESSING:
        #for proc in jobs:
        #    proc.join() 
            
        while any([p.is_alive() for p in jobs]):
            print( format(status) )
            sleep(1)
        print("Done.")
            
#test(shotlists, MULTIPROCESSING = True)

# %%
from multiprocessing import RawArray

def calculate_pixel_fiber_intersec(shotlist, fibers, pixelsize, fxx, fyy, FIBERD, MULTIPROCESSING = True):
    # USING SPARSE MATRICES!!!
    from scipy.sparse import lil_matrix as sparse_matrix
    from scipy.sparse import csr_matrix

    #csr_matrix

    #from numpy import array as sparse_matrix
    import time

    print( "Calculating fiber/pixel weight maps..." )


    def worker(shot, shotfibers, pixels, shotfxx, shotfyy, pixelsize, FIBERD, nI, idx, status):
        I = sparse_matrix( np.zeros([len(pixels),len(shotfibers)], dtype=np.float) ) # I is the pixel fiber intersection matrix
        #I = np.array( np.zeros([len(pixels),len(shotfibers)], dtype=np.float) ) # I is the pixel fiber intersection matrix

        fib_range = numpy.arange( len(shotfibers) )
        Npix = len(pixels)
        pix_range = range( Npix )

        NNN = 0

        start_time = time.time()
        npix = len(pix_range)

        for ip in pix_range:
            status[idx] = float(ip)/float(Npix)

            p = pixels[ip]

            px,py = p[1],p[2]
            #calculate distances of all fibers of this shot to the current pixel
            dd_sq = (shotfxx-px)**2. + (shotfyy-py)**2. 

            # Find which fibers of this shot could possibly intersect with the current pixel
            # in the intersection filter, only shotfibers which overlap the pixel are considered.
            # We only look at shotfibers wich are not further than 
            # sqrt(2) * pixelsize/2 + fiberd/2 
            ii = ( dd_sq < (pixelsize/2. *  1.414 + FIBERD/2.)**2.)
            # create a polygon describing the current pixel
            ppxx,ppyy = pixel(px,py,pixelsize)
            pixel_poly = list( zip(ppxx,ppyy) )

            if any(ii):
                for ifib in fib_range[ii]:
                    fx = shotfxx[ifib]
                    fy = shotfyy[ifib]

                    NNN += 1
                    fpxx,fpyy = circle(fx,fy,FIBERD)
                    fiber_poly = list( zip(fpxx,fpyy) )
                    fiber_array = PolygonIntersect.toPointsArray(fiber_poly)
                    pixel_array = PolygonIntersect.toPointsArray(pixel_poly)
                    # calculate intersection area
                    iA = PolygonIntersect.intersectionArea(fiber_array, pixel_array)
                    # Now, the flux of a given fiber (at a given wavelength)
                    # will be assigned to a pixel weighted by the fraction of the 
                    # total fiber area that is overlapping with the pixel.
                    I[ip,ifib]  = iA#/fiberA


        #nI[shot] =  I.T/fiberA 
        nI[shot] =  csr_matrix( I.T/fiberA ) 

        #print("Done.")

        elapsed_time = time.time() - start_time
        #print("elapsed_time: {:.2f}".format(elapsed_time) )

        
    nI = {}
    manager = multiprocessing.Manager()
    nI = manager.dict()
    jobs = []
    status = RawArray('d', len(shotlist))
    
    for idx, shot in enumerate(shotlist):
        print("Launching shot {} : {}".format(idx, shot))

        jj = fibers["shot"] == shot
        shotfibers = fibers[jj]
        shotfxx = fxx[jj]
        shotfyy = fyy[jj]

        if MULTIPROCESSING:
            
            p = multiprocessing.Process(target=worker, \
                    args=(shot, shotfibers, pixels, shotfxx, shotfyy, pixelsize, FIBERD, nI, idx, status))
            jobs.append(p)
            p.start()
        else:
            worker(shot, shotfibers, pixels, shotfxx, shotfyy, pixelsize, FIBERD, nI)

    if MULTIPROCESSING:
        #for proc in jobs:
        #    proc.join()
         
        s = " | ".join( ["{:5d} ".format(i) for i in range(len(shotlist))])
        print(s)
        while any([p.is_alive() for p in jobs]):
            sstatus = " | ".join( ["{:5.1f}%".format ( s*100 ) for s  in status]   ) 
            sys.stdout.write( '\r'* len(sstatus))
            sys.stdout.write(sstatus)
            sys.stdout.flush()

            sleep(1)
        print("")
        print("Done.")

    print("All done.")

    return dict(nI)

#nI = calculate_pixel_fiber_intersec(shotlists, fibers, pixelsize, FIBERD)

# %%
from multiprocessing import RawArray

def calculate_pixel_fiber_intersecNew(shotlist, fibers, pixelsize, fxx, fyy, FIBERD, MULTIPROCESSING = True):
    # USING SPARSE MATRICES!!!
    from scipy.sparse import lil_matrix as sparse_matrix
    from scipy.sparse import csr_matrix

    #csr_matrix

    #from numpy import array as sparse_matrix
    import time

    print( "Calculating fiber/pixel weight maps..." )

    nI = {}

    manager = multiprocessing.Manager()
    nI = manager.dict()
    jobs = []


    def worker(shot, shotfibers, pixels, shotfxx, shotfyy, pixelsize, FIBERD, nI, idx, status):
        I = sparse_matrix( np.zeros([len(pixels),len(shotfibers)], dtype=np.float) ) # I is the pixel fiber intersection matrix
        #I = np.array( np.zeros([len(pixels),len(shotfibers)], dtype=np.float) ) # I is the pixel fiber intersection matrix

        fib_range = numpy.arange( len(shotfibers) )
        Npix = len(pixels)
        pix_range = range( Npix )

        NNN = 0

        start_time = time.time()
        npix = len(pix_range)

        for ip in pix_range:
            status[idx] = float(ip)/float(Npix)

            p = pixels[ip]

            px,py = p[1],p[2]
            #calculate distances of all fibers of this shot to the current pixel
            dd_sq = (shotfxx-px)**2. + (shotfyy-py)**2. 

            # Find which fibers of this shot could possibly intersect with the current pixel
            # in the intersection filter, only shotfibers which overlap the pixel are considered.
            # We only look at shotfibers wich are not further than 
            # sqrt(2) * pixelsize/2 + fiberd/2 
            ii = ( dd_sq < (pixelsize/2. *  1.414 + FIBERD/2.)**2.)
            # create a polygon describing the current pixel
            ppxx,ppyy = pixel(px,py,pixelsize)
            pixel_poly = list( zip(ppxx,ppyy) )

            if any(ii):
                for ifib in fib_range[ii]:
                    fx = shotfxx[ifib]
                    fy = shotfyy[ifib]

                    NNN += 1
                    fpxx,fpyy = circle(fx,fy,FIBERD)
                    fiber_poly = list( zip(fpxx,fpyy) )
                    fiber_array = PolygonIntersect.toPointsArray(fiber_poly)
                    pixel_array = PolygonIntersect.toPointsArray(pixel_poly)
                    # calculate intersection area
                    iA = PolygonIntersect.intersectionArea(fiber_array, pixel_array)
                    # Now, the flux of a given fiber (at a given wavelength)
                    # will be assigned to a pixel weighted by the fraction of the 
                    # total fiber area that is overlapping with the pixel.
                    I[ip,ifib]  = iA#/fiberA


        #nI[shot] =  I.T/fiberA 
        nI[shot] =  csr_matrix( I.T/fiberA ) 

        #print("Done.")

        elapsed_time = time.time() - start_time
        #print("elapsed_time: {:.2f}".format(elapsed_time) )


    status = RawArray('d', len(shotlist))
    
    
    if MULTIPROCESSING:
        pool = multiprocessing.Pool()
    
    for idx, shot in enumerate(shotlist):
        print("Launching shot {} : {}".format(idx, shot))

        jj = fibers["shot"] == shot
        shotfibers = fibers[jj]
        shotfxx = fxx[jj]
        shotfyy = fyy[jj]

        if MULTIPROCESSING:
            pool.apply_async(worker, \
                             args=(shot, shotfibers, pixels, shotfxx, shotfyy, pixelsize, FIBERD, nI, idx, status))
        else:
            worker(shot, shotfibers, pixels, shotfxx, shotfyy, pixelsize, FIBERD, nI)

    if MULTIPROCESSING:
        #for proc in jobs:
        #    proc.join()
         
        s = "|".join( ["{:5d} ".format(i) for i in range(len(shotlist))])
        print(s)
        while any([p.is_alive() for p in jobs]):
            sstatus = "|".join( ["{:5.1f}%".format ( s*100 ) for s  in status]   ) 
            sys.stdout.write( '\r'* len(sstatus))
            sys.stdout.write(sstatus)
            sys.stdout.flush()

            sleep(1)
        print("")
        # These lines are probably not necessery anymore as we 
        # waited explicitly for all workers to finish.
        pool.close()
        pools.join()
        print("Done.")

    print("All done.")

    return nI

#nI = calculate_pixel_fiber_intersec(shotlists, fibers, pixelsize, fxx, fyy, FIBERD)

# %%
# Multiprocessing testing
if False:
    status = RawArray('d', len(shotlist))


    pool = multiprocessing.Pool()

    def worker(shot, shotfibers, pixels, shotfxx, shotfyy, pixelsize, FIBERD, nI, idx, status):
        for i in range(5):
            status[idx] = i
            sleep(1)

            pool.apply_async(worker, \
                             args=(shot, shotfibers, pixels, shotfxx, shotfyy, pixelsize, FIBERD, nI, idx, status))

    s = "|".join( ["{:5d} ".format(i) for i in range(len(shotlist))])
    print(s)
    while any([p.is_alive() for p in jobs]):
        sstatus = "|".join( ["{:5.1f}%".format ( s*100 ) for s  in status]   ) 
        sys.stdout.write( '\r'* len(sstatus))
        sys.stdout.write(sstatus)
        sys.stdout.flush()

        sleep(1)
    print("")
    # These lines are probably not necessery anymore as we 
    # waited explicitly for all workers to finish.
    pool.close()
    pool.join()
    print("Done.")

    print("All done.")

# %% [markdown]
# ## Create Cube

# %%
def build_cubes(shotlist, fibers, allspec, nI, X,Y,nx, ny, pixelsize, fiberA, wlgrid, wlstart, wlstop):
    print("Creating cube(s)...")
    cube = {}
    W = {}

    for shot in shotlist:
        print("shot {}".format(shot))
        shotspec = allspec[fibers["shot"] == shot]
        ##  shotnormalisations = normalisations[fibers["shot"] == shot]
        # with the help of the intersection matix
        # the pixel values of each wavelength slice are simply the dot product of that matrix (transposed) in the vector
        # of all the fiber values at a give wavelength.
        cube[shot] = np.zeros( [shotspec.shape[1],ny,nx] )

        #W[shot] = np.sum(nI[shot]*fiberA,axis=0)/(pixelsize**2.)
        # this bacame necessary when convarting to sparce matrices
        W[shot] = np.array( np.sum(nI[shot]*fiberA,axis=0)/(pixelsize**2.) )[0]

        # calculate median flux level of all fibers
        kk = (wlgrid > wlstart) * (wlgrid < wlstop) 
        mm = np.median(shotspec[:,kk],axis=1)

        nshotspec = (shotspec.transpose()/mm).transpose()

        IT = nI[shot].transpose()

        def stats(a):
            print("min,max = ", a.min, a.max() )
            print("mean = ", mean(a) )
            print("std = ", std(a) )

        if True:
            for iwl in range(shotspec.shape[1]): # for each wavelength

                if iwl % 100 == 0:
                    s = "WL: %6d %14.6f" % ( iwl,wlgrid[iwl] )
                    sys.stdout.write( '\r'* len(s))
                    sys.stdout.write(s)
                    sys.stdout.flush()

                if True:
                    # usual fast way by matrix multiplication
                    imf2 = IT.dot(shotspec[:,iwl])
                    ii = W[shot] > 0. # prevent zero div error
                    #1/0
                    imf2[ii] = imf2[ii]/W[shot][ii]

                    im2 = imf2.reshape(X.shape)

                    PLOT = False 
                    if PLOT:
                        # PLOT
                        X=0.
                        Y=0.
                        vmin=-20.
                        vmax=20.
                        cmap =  plt.cm.jet 
                        s = plt.subplot(111)
                        dd = np.sqrt((fxx-X)**2. + (fyy-Y)**2.)
                        jj = dd < 50.
                        for ifib,fx,fy in zip(fibers["count"][jj], fxx[jj],fyy[jj]):
                            fpxx,fpyy = circle(fx,fy,FIBERD)
                            #s.plot([fx],[fy],'k.')
                            val = np.nanmedian( shotspec[int(ifib),100:-100] )
                            c = (val-vmin)/(vmax-vmin)

                            s.fill( fpxx,fpyy, facecolor=cmap(c),edgecolor='None',linewidth=1.)
                            #s.text(fx,fy,"{:d}".format(int(ifib) ))
                        plt.show()

                cube[shot][iwl] = im2

            print("")

    # In[156]:


    wstart = wlgrid[0]
    wstep  = wlgrid[1]-wlgrid[0]
    return cube, W, wstart, wstep


#cube, W, wstart, wstep = \
#    build_cubes(shotlist, fibers, allspec, nI, X,Y,nx, ny, pixelsize, fiberA, wlgrid, wlstart, wlstop)

# %% [markdown]
# ## save output

# %%
def stack_cube(cube, shotlist):
    print("Stacking {} cubes ...".format(len(cube)))

    import numpy as np
    cc = np.array( [cube[shot] for shot in shotlist] )


    cc[cc == 0.] = np.nan

    mc = np.zeros_like(cc[0])

    ymin  = 0

    N = 20
    while ymin < mc.shape[1]:
        xmin  = 0
        while xmin < mc.shape[1]:    
            mc[:,ymin:ymin+N,xmin:xmin+N] = np.nanmedian( cc[:,:,ymin:ymin+N,xmin:xmin+N], axis=0 )
            xmin += N
        ymin += N

    cc[cc == 0.] = np.nan

    cc[np.isnan(cc)] = 0.
    return cc, mc
    
def save_cube(mc, xx, yy, pixelsize, RA0, DEC0, wstart, wstep, outfilename):
    print("Saving cube to {}.".format(outfilename))
    #xc,yc are the cube pixel indices that
    #correspond to RA0 and DEC0 and x = 0" and y = 0"
    xc = -xx[0]/pixelsize + 1 
    yc = -yy[0]/pixelsize + 1 

    h2d = create_2D_header(xc, yc, RA0, DEC0, pixelsize)
    h = create_3D_header(xc, yc, RA0, DEC0, pixelsize,wstart,wstep)

    hdu = fits.PrimaryHDU(mc,h)

    hdu.writeto(outfilename,overwrite=True)
    print("Wrote {}.".format(outfilename))
    
#outfilename = "outcube_{}_{}.fits.gz".format("median","-".join(ifuslots))
#save_cube(cube, xx, yy, pixelsize, RA0, DEC0, wstart, wstep, outfilename)

# %% [markdown]
# # show some slice

# %%
if False:
    c = spectrum.readSpectrum(outfilename)

    from matplotlib import pyplot as plt

    plt.imshow(c.data[740])

# %% [markdown]
# ## Run over multiple IFUs

# %%
RA0 = None 
DEC0 = None
FIBERD = 1.5
nx = None
ny = None
pixelsize = .5
fiberA = np.pi*(FIBERD/2.)**2.
write_single_cubes = False    
pa = 0.

# %%
basepath = "/home/idies/workspace/Storage/mxhf/persistent/mygama09/gama_recon/"
outpath  = "/home/idies/workspace/Storage/mxhf/persistent/mygama09/data"
SKIP_EXISTING = True

# %%
print(os.path.exists(basepath))
print(os.path.exists(outpath))
# Out:
# True
# True

# %%
shotlist = {}
__ = """20191203_0000024
20191221_0000022
20191203_0000025
20191222_0000023
20191221_0000023
20191224_0000024
20191222_0000024
20191229_0000023
20191231_0000024
20200101_0000019
20191231_0000025
20200101_0000020"""
shotlist["gama09E"] = __.split()


__ = """20200118_0000017
20200215_0000016
20200119_0000018
20200217_0000014
20200124_0000016
20200217_0000015
20200119_0000019
20200225_0000016
20200125_0000020
20200315_0000012
20200126_0000020"""
shotlist["gama09F"] = __.split()

__ = """
20200126_0000021
20201113_0000027
20200127_0000018
20201113_0000028
20200127_0000019
20201115_0000023
20200129_0000018
20201116_0000030
20200213_0000015
20200129_0000019"""
shotlist["gama09G"] = __.split()




uifuslots = [13, 14, 15, 16, 21,   \
             22, 23, 24, 25, 26,   \
             27, 28, 31, 32, 33,   \
             34, 35, 36, 37, 38,   \
             41, 42, 43, 44, 45,   \
             46, 47, 48, 52, 53,   \
             62, 63, 67, 68, 71,   \
             72, 73, 74, 75, 76,   \
             77, 79, 81, 82, 83,   \
             84, 85, 86, 87, 88,   \
             91, 92, 93, 94, 95,   \
             96, 97, 98, 103, 104, \
             105, 106]


#ifus = [84, 75, 85, 74]
#ifus = [25, 35, 15, 34]

shotlists = shotlist["gama09E"][:] + shotlist["gama09F"][:]  + shotlist["gama09G"][:]

ifus = uifuslots
shotlists = ['20200129_0000019']

#print("###########################")
#print("Processing field {} ".format(field))
#print("###########################")
#continue

outfilename = os.path.join( outpath, "{}_{}.fits.gz".format("gama09EFG","_".join([str(ifu) for ifu in ifus])) )

# %%
#save
#pickle.dump( [fibers, allspec], open( "save.p", "wb" ) )

# %%
#load
fibers, allspec = pickle.load( open( "save.p", "rb" ) )

# %%
# load data
fibers, allspec = load_data(basepath, shotlists, ifus)
# Out:
# Loading shot 20200129_0000019
#   IFU slot 13
#   IFU slot 14
#   IFU slot 15
#   IFU slot 16
#   IFU slot 21
#   IFU slot 22
#   IFU slot 23
#   IFU slot 24
#   IFU slot 25
#   IFU slot 26
#   IFU slot 27
#   IFU slot 28
#   IFU slot 31
#   IFU slot 32
#   IFU slot 33
#   IFU slot 34
#   IFU slot 35
#   IFU slot 36
#   IFU slot 37
#   IFU slot 38
#   IFU slot 41
#   IFU slot 42
#   IFU slot 43
#   IFU slot 44
#   IFU slot 45
#   IFU slot 46
#   IFU slot 47
#   IFU slot 48
#   IFU slot 52
#   IFU slot 53
#   IFU slot 62
#   IFU slot 63
#   IFU slot 67
#   IFU slot 68
#   IFU slot 71
#   IFU slot 72
#   IFU slot 73
#   IFU slot 74
#   IFU slot 75
#   IFU slot 76
#   IFU slot 77
#   IFU slot 79
#   IFU slot 81
#   IFU slot 82
#   IFU slot 83
#   IFU slot 84
#   IFU slot 85
#   IFU slot 86
#   IFU slot 87
#   IFU slot 88
#   IFU slot 91
#   IFU slot 92
#   IFU slot 93
#   IFU slot 94
#   IFU slot 95
#   IFU slot 96
#   IFU slot 97
#   IFU slot 98
#   IFU slot 103
#   IFU slot 104
#   IFU slot 105
#   IFU slot 106
# len(allspec):  83328
# len(fibers):  83328
# Done.

# %%
# compute pitch and location of pixel grid
#pixels,xx,yy,X,Y,fxx,fyy,nx,ny = compute_pixel_grid(fibers)
pixels,xx,yy,X,Y,fxx,fyy,nx,ny, RA0, DEC0 = find_pixel_grid(fibers)
# Out:
# Set tangent point for projection to RA0 = 130.056599 and DEC0  = 2.349576.
# Extent in RA : 1033.5 "
# Extent in Dec : 1032.7 "

# %%
# save
#pickle.dump( nI, open( "20200129_0000019.p", "wb" ) )

# %%
# load
nI = pickle.load( open( "nI.p", "rb" ) )

# %%
# compute fiber to pixel flux mappings
nI = calculate_pixel_fiber_intersec(shotlists, fibers, pixelsize, fxx, fyy, FIBERD)
# Out:
# Calculating fiber/pixel weight maps...
# Launching shot 0 : 20200129_0000019
#     0
#   0.0%
# Process Process-57:
# Traceback (most recent call last):
#   File "/home/idies/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/idies/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-36-120a63f75667>", line 23, in worker
#     I = sparse_matrix( np.zeros([len(pixels),len(shotfibers)], dtype=np.float) ) # I is the pixel fiber intersection matrix
# MemoryError: Unable to allocate 2.59 TiB for an array with shape (4268355, 83328) and data type float64
# Done.
# All done.

# %%
for shot in shotlists:
    print("#############################################")
    print("Building cube for shot {} ...".format(shot))
    print("#############################################")
    cube, W, wstart, wstep = \
        build_cubes([shot], fibers, allspec, nI, X,Y,nx, ny, pixelsize, fiberA, wlgrid, wlstart, wlstop)

    outfilename = os.path.join(outpath, "mfcube{}.fits".format(shot))
    save_cube(cube[shot], xx, yy, pixelsize, RA0, DEC0, wstart, wstep, outfilename)
# Out:
# #############################################
# Building cube for shot 20191203_0000024 ...
# #############################################
# Creating cube(s)...
# shot 20191203_0000024
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191203_0000024.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191203_0000024.fits.
# #############################################
# Building cube for shot 20191221_0000022 ...
# #############################################
# Creating cube(s)...
# shot 20191221_0000022
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191221_0000022.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191221_0000022.fits.
# #############################################
# Building cube for shot 20191203_0000025 ...
# #############################################
# Creating cube(s)...
# shot 20191203_0000025
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191203_0000025.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191203_0000025.fits.
# #############################################
# Building cube for shot 20191222_0000023 ...
# #############################################
# Creating cube(s)...
# shot 20191222_0000023
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191222_0000023.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191222_0000023.fits.
# #############################################
# Building cube for shot 20191221_0000023 ...
# #############################################
# Creating cube(s)...
# shot 20191221_0000023
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191221_0000023.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191221_0000023.fits.
# #############################################
# Building cube for shot 20191224_0000024 ...
# #############################################
# Creating cube(s)...
# shot 20191224_0000024
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191224_0000024.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191224_0000024.fits.
# #############################################
# Building cube for shot 20191222_0000024 ...
# #############################################
# Creating cube(s)...
# shot 20191222_0000024
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191222_0000024.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191222_0000024.fits.
# #############################################
# Building cube for shot 20191229_0000023 ...
# #############################################
# Creating cube(s)...
# shot 20191229_0000023
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191229_0000023.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191229_0000023.fits.
# #############################################
# Building cube for shot 20191231_0000024 ...
# #############################################
# Creating cube(s)...
# shot 20191231_0000024
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191231_0000024.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191231_0000024.fits.
# #############################################
# Building cube for shot 20200101_0000019 ...
# #############################################
# Creating cube(s)...
# shot 20200101_0000019
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200101_0000019.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200101_0000019.fits.
# #############################################
# Building cube for shot 20191231_0000025 ...
# #############################################
# Creating cube(s)...
# shot 20191231_0000025
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191231_0000025.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20191231_0000025.fits.
# #############################################
# Building cube for shot 20200101_0000020 ...
# #############################################
# Creating cube(s)...
# shot 20200101_0000020
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200101_0000020.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200101_0000020.fits.
# #############################################
# Building cube for shot 20200118_0000017 ...
# #############################################
# Creating cube(s)...
# shot 20200118_0000017
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200118_0000017.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200118_0000017.fits.
# #############################################
# Building cube for shot 20200215_0000016 ...
# #############################################
# Creating cube(s)...
# shot 20200215_0000016
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200215_0000016.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200215_0000016.fits.
# #############################################
# Building cube for shot 20200119_0000018 ...
# #############################################
# Creating cube(s)...
# shot 20200119_0000018
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200119_0000018.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200119_0000018.fits.
# #############################################
# Building cube for shot 20200217_0000014 ...
# #############################################
# Creating cube(s)...
# shot 20200217_0000014
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200217_0000014.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200217_0000014.fits.
# #############################################
# Building cube for shot 20200124_0000016 ...
# #############################################
# Creating cube(s)...
# shot 20200124_0000016
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200124_0000016.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200124_0000016.fits.
# #############################################
# Building cube for shot 20200217_0000015 ...
# #############################################
# Creating cube(s)...
# shot 20200217_0000015
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200217_0000015.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200217_0000015.fits.
# #############################################
# Building cube for shot 20200119_0000019 ...
# #############################################
# Creating cube(s)...
# shot 20200119_0000019
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200119_0000019.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200119_0000019.fits.
# #############################################
# Building cube for shot 20200225_0000016 ...
# #############################################
# Creating cube(s)...
# shot 20200225_0000016
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200225_0000016.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200225_0000016.fits.
# #############################################
# Building cube for shot 20200125_0000020 ...
# #############################################
# Creating cube(s)...
# shot 20200125_0000020
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200125_0000020.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200125_0000020.fits.
# #############################################
# Building cube for shot 20200315_0000012 ...
# #############################################
# Creating cube(s)...
# shot 20200315_0000012
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200315_0000012.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200315_0000012.fits.
# #############################################
# Building cube for shot 20200126_0000020 ...
# #############################################
# Creating cube(s)...
# shot 20200126_0000020
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200126_0000020.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200126_0000020.fits.
# #############################################
# Building cube for shot 20200126_0000021 ...
# #############################################
# Creating cube(s)...
# shot 20200126_0000021
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200126_0000021.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200126_0000021.fits.
# #############################################
# Building cube for shot 20201113_0000027 ...
# #############################################
# Creating cube(s)...
# shot 20201113_0000027
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20201113_0000027.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20201113_0000027.fits.
# #############################################
# Building cube for shot 20200127_0000018 ...
# #############################################
# Creating cube(s)...
# shot 20200127_0000018
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200127_0000018.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200127_0000018.fits.
# #############################################
# Building cube for shot 20201113_0000028 ...
# #############################################
# Creating cube(s)...
# shot 20201113_0000028
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20201113_0000028.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20201113_0000028.fits.
# #############################################
# Building cube for shot 20200127_0000019 ...
# #############################################
# Creating cube(s)...
# shot 20200127_0000019
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200127_0000019.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200127_0000019.fits.
# #############################################
# Building cube for shot 20201115_0000023 ...
# #############################################
# Creating cube(s)...
# shot 20201115_0000023
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20201115_0000023.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20201115_0000023.fits.
# #############################################
# Building cube for shot 20200129_0000018 ...
# #############################################
# Creating cube(s)...
# shot 20200129_0000018
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200129_0000018.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200129_0000018.fits.
# #############################################
# Building cube for shot 20201116_0000030 ...
# #############################################
# Creating cube(s)...
# shot 20201116_0000030
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20201116_0000030.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20201116_0000030.fits.
# #############################################
# Building cube for shot 20200213_0000015 ...
# #############################################
# Creating cube(s)...
# shot 20200213_0000015
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200213_0000015.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200213_0000015.fits.
# #############################################
# Building cube for shot 20200129_0000019 ...
# #############################################
# Creating cube(s)...
# shot 20200129_0000019
# WL:   1000    5470.000000
# Saving cube to /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200129_0000019.fits.
# Wrote /home/idies/workspace/Storage/mxhf/persistent/mygama09/data/mfcube20200129_0000019.fits.

# %%
# build cubes
cube, W, wstart, wstep = \
    build_cubes(shotlists, fibers, allspec, nI, X,Y,nx, ny, pixelsize, fiberA, wlgrid, wlstart, wlstop)

# Free some memory
#nI = None 
W = None

# %%
# stack 
cc, mc = stack_cube(cube, shotlists)

# %%
# & save
save_cube(mc, xx, yy, pixelsize, RA0, DEC0, wstart, wstep, outfilename)

# %%
# !ls /home/idies/workspace/Storage/mxhf/persistent/mygama09

# %%
ifus

# %%
basepath

# %% [markdown]
# ## Old

# %%
shotlist = {}
__ = """20191203_0000024
20191221_0000022
20191203_0000025
20191222_0000023
20191221_0000023
20191224_0000024
20191222_0000024
20191229_0000023
20191231_0000024
20200101_0000019
20191231_0000025
20200101_0000020"""
shotlist["gama09E"] = __.split()


__ = """20200118_0000017
20200215_0000016
20200119_0000018
20200217_0000014
20200124_0000016
20200217_0000015
20200119_0000019
20200225_0000016
20200125_0000020
20200315_0000012
20200126_0000020"""
shotlist["gama09F"] = __.split()



uifuslots = [13, 14, 15, 16, 21,   \
             22, 23, 24, 25, 26,   \
             27, 28, 31, 32, 33,   \
             34, 35, 36, 37, 38,   \
             41, 42, 43, 44, 45,   \
             46, 47, 48, 52, 53,   \
             62, 63, 67, 68, 71,   \
             72, 73, 74, 75, 76,   \
             77, 79, 81, 82, 83,   \
             84, 85, 86, 87, 88,   \
             91, 92, 93, 94, 95,   \
             96, 97, 98, 103, 104, \
             105, 106]

fields = ["gama09E", "gama09F"]
for field in fields:
    for ifu in uifuslots:
        print("###########################")
        print("Processing field {} ifu {}".format(field, ifu))
        print("###########################")
        #continue
        
        outfilename = os.path.join( outpath, "{}_{:03d}.fits.gz".format(field,ifu) )
        if os.path.exists(outfilename) and SKIP_EXISTING:
            print("{} exists, skipping ...".format(outfilename))
            continue

        # load data
        fibers, allspec = load_data(basepath, shotlist[field], [ifu])

        # compute pith and location of pixel grid
        #pixels,xx,yy,X,Y,fxx,fyy,nx,ny = compute_pixel_grid(fibers)
        pixels,xx,yy,X,Y,fxx,fyy,nx,ny, RA0, DEC0 = find_pixel_grid(fibers)

        # compute fiber to pixel flux mappings
        nI = calculate_pixel_fiber_intersec(shotlist[field], fibers, pixelsize, FIBERD)

        # build cubes
        cube, W, wstart, wstep = \
            build_cubes(shotlist[field], fibers, allspec, nI, X,Y,nx, ny, pixelsize, fiberA, wlgrid, wlstart, wlstop)

        # Free some memory
        nI = None 
        W = None

        # stack & save
        cc, mc = stack_cube(cube, shotlist[field])

        # stack & save
        save_cube(mc, xx, yy, pixelsize, RA0, DEC0, wstart, wstep, outfilename)
